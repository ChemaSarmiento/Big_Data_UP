# %%
from pyspark.sql import SparkSession
from datetime import datetime

# %%
warehouse_location = '/user/war_tweets'

# %%
spark = SparkSession \
    .builder \
    .appName("App de Spark para Tweets") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://cluster-1105-m.c.chemackana-project.internal:41685">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# !hdfs dfs -mkdir /user/war_tweets
# !wget https://storage.googleapis.com/public-bucket-up-2022/war.txt
# !hdfs dfs -copyFromLocal war.txt /user/war_tweets
# !hdfs dfs -ls /user/war_tweets
# Out:
# --2022-04-18 17:09:16--  https://storage.googleapis.com/public-bucket-up-2022/war.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.6.128, 142.250.128.128, 142.250.103.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.6.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23663541134 (22G) [text/plain]
# Saving to: ‘war.txt’
#
# war.txt             100%[===================>]  22.04G   112MB/s    in 3m 7s
#
# 2022-04-18 17:12:24 (121 MB/s) - ‘war.txt’ saved [23663541134/23663541134]
#
# Found 1 items
# -rw-r--r--   2 root hadoop 23663541134 2022-04-18 17:15 /user/war_tweets/war.txt

# %%
path = warehouse_location + "/war.txt"
tweets = spark.read.json(path, lineSep="\n")
# Out:
# 22/04/18 17:21:19 WARN org.apache.spark.sql.catalyst.util.package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %% [markdown]
# ## Manejando acciones y transformaciones

# %%
tweets.columns
# Out:
# ['_type',
#  'card',
#  'cashtags',
#  'content',
#  'conversationId',
#  'coordinates',
#  'date',
#  'hashtags',
#  'id',
#  'inReplyToTweetId',
#  'inReplyToUser',
#  'lang',
#  'likeCount',
#  'media',
#  'mentionedUsers',
#  'outlinks',
#  'place',
#  'quoteCount',
#  'quotedTweet',
#  'renderedContent',
#  'replyCount',
#  'retweetCount',
#  'retweetedTweet',
#  'source',
#  'sourceLabel',
#  'sourceUrl',
#  'tcooutlinks',
#  'url',
#  'user']

# %%
tweets.printSchema()
#este esquema esta inferido, si tenemos muchisimos datos, nosotros tenemos que definir el esquema para que las operaciones sean correctas.
# Out:
# root
#  |-- _type: string (nullable = true)
#  |-- card: struct (nullable = true)
#  |    |-- _type: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- thumbnailUrl: string (nullable = true)
#  |    |-- title: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- cashtags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- content: string (nullable = true)
#  |-- conversationId: long (nullable = true)
#  |-- coordinates: struct (nullable = true)
#  |    |-- _type: string (nullable = true)
#  |    |-- latitude: double (nullable = true)
#  |    |-- longitude: double (nullable = true)
#  |-- date: string (nullable = true)
#  |-- hashtags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- id: long (nullable = true)
#  |-- inReplyToTweetId: long (nullable = true)
#  |-- inReplyToUser: struct (nullable = true)
#  |    |-- _type: string (nullable = true)
#  |    |-- created: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- descriptionUrls: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- tcourl: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- displayname: string (nullable = true)
#  |    |-- favouritesCount: long (nullable = true)
#  |    |-- followersCount: long (nullable = true)
#  |    |-- friendsCount: long (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- label: struct (nullable = true)
#  |    |    |-- _type: string (nullable = true)
#  |    |    |-- badgeUrl: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- longDescription: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- linkTcourl: string (nullable = true)
#  |    |-- linkUrl: string (nullable = true)
#  |    |-- listedCount: long (nullable = true)
#  |    |-- location: string (nullable = true)
#  |    |-- mediaCount: long (nullable = true)
#  |    |-- profileBannerUrl: string (nullable = true)
#  |    |-- profileImageUrl: string (nullable = true)
#  |    |-- protected: boolean (nullable = true)
#  |    |-- rawDescription: string (nullable = true)
#  |    |-- statusesCount: long (nullable = true)
#  |    |-- url: string (nullable = true)
#  |    |-- username: string (nullable = true)
#  |    |-- verified: boolean (nullable = true)
#  |-- lang: string (nullable = true)
#  |-- likeCount: long (nullable = true)
#  |-- media: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- _type: string (nullable = true)
#  |    |    |-- duration: double (nullable = true)
#  |    |    |-- fullUrl: string (nullable = true)
#  |    |    |-- previewUrl: string (nullable = true)
#  |    |    |-- thumbnailUrl: string (nullable = true)
#  |    |    |-- variants: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- _type: string (nullable = true)
#  |    |    |    |    |-- bitrate: long (nullable = true)
#  |    |    |    |    |-- contentType: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- views: long (nullable = true)
#  |-- mentionedUsers: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- _type: string (nullable = true)
#  |    |    |-- created: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- descriptionUrls: string (nullable = true)
#  |    |    |-- displayname: string (nullable = true)
#  |    |    |-- favouritesCount: string (nullable = true)
#  |    |    |-- followersCount: string (nullable = true)
#  |    |    |-- friendsCount: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- linkTcourl: string (nullable = true)
#  |    |    |-- linkUrl: string (nullable = true)
#  |    |    |-- listedCount: string (nullable = true)
#  |    |    |-- location: string (nullable = true)
#  |    |    |-- mediaCount: string (nullable = true)
#  |    |    |-- profileBannerUrl: string (nullable = true)
#  |    |    |-- profileImageUrl: string (nullable = true)
#  |    |    |-- protected: string (nullable = true)
#  |    |    |-- rawDescription: string (nullable = true)
#  |    |    |-- statusesCount: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- username: string (nullable = true)
#  |    |    |-- verified: string (nullable = true)
#  |-- outlinks: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- place: struct (nullable = true)
#  |    |-- _type: string (nullable = true)
#  |    |-- country: string (nullable = true)
#  |    |-- countryCode: string (nullable = true)
#  |    |-- fullName: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |-- quoteCount: long (nullable = true)
#  |-- quotedTweet: struct (nullable = true)
#  |    |-- _type: string (nullable = true)
#  |    |-- card: struct (nullable = true)
#  |    |    |-- _type: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- thumbnailUrl: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- cashtags: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- content: string (nullable = true)
#  |    |-- conversationId: long (nullable = true)
#  |    |-- coordinates: struct (nullable = true)
#  |    |    |-- _type: string (nullable = true)
#  |    |    |-- latitude: double (nullable = true)
#  |    |    |-- longitude: double (nullable = true)
#  |    |-- date: string (nullable = true)
#  |    |-- hashtags: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- id: long (nullable = true)
#  |    |-- inReplyToTweetId: long (nullable = true)
#  |    |-- inReplyToUser: struct (nullable = true)
#  |    |    |-- _type: string (nullable = true)
#  |    |    |-- created: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- descriptionUrls: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- tcourl: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- displayname: string (nullable = true)
#  |    |    |-- favouritesCount: long (nullable = true)
#  |    |    |-- followersCount: long (nullable = true)
#  |    |    |-- friendsCount: long (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- label: struct (nullable = true)
#  |    |    |    |-- _type: string (nullable = true)
#  |    |    |    |-- badgeUrl: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- longDescription: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- linkTcourl: string (nullable = true)
#  |    |    |-- linkUrl: string (nullable = true)
#  |    |    |-- listedCount: long (nullable = true)
#  |    |    |-- location: string (nullable = true)
#  |    |    |-- mediaCount: long (nullable = true)
#  |    |    |-- profileBannerUrl: string (nullable = true)
#  |    |    |-- profileImageUrl: string (nullable = true)
#  |    |    |-- protected: boolean (nullable = true)
#  |    |    |-- rawDescription: string (nullable = true)
#  |    |    |-- statusesCount: long (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- username: string (nullable = true)
#  |    |    |-- verified: boolean (nullable = true)
#  |    |-- lang: string (nullable = true)
#  |    |-- likeCount: long (nullable = true)
#  |    |-- media: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- _type: string (nullable = true)
#  |    |    |    |-- duration: double (nullable = true)
#  |    |    |    |-- fullUrl: string (nullable = true)
#  |    |    |    |-- previewUrl: string (nullable = true)
#  |    |    |    |-- thumbnailUrl: string (nullable = true)
#  |    |    |    |-- variants: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- _type: string (nullable = true)
#  |    |    |    |    |    |-- bitrate: long (nullable = true)
#  |    |    |    |    |    |-- contentType: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- views: long (nullable = true)
#  |    |-- mentionedUsers: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- _type: string (nullable = true)
#  |    |    |    |-- created: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- descriptionUrls: string (nullable = true)
#  |    |    |    |-- displayname: string (nullable = true)
#  |    |    |    |-- favouritesCount: string (nullable = true)
#  |    |    |    |-- followersCount: string (nullable = true)
#  |    |    |    |-- friendsCount: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- linkTcourl: string (nullable = true)
#  |    |    |    |-- linkUrl: string (nullable = true)
#  |    |    |    |-- listedCount: string (nullable = true)
#  |    |    |    |-- location: string (nullable = true)
#  |    |    |    |-- mediaCount: string (nullable = true)
#  |    |    |    |-- profileBannerUrl: string (nullable = true)
#  |    |    |    |-- profileImageUrl: string (nullable = true)
#  |    |    |    |-- protected: string (nullable = true)
#  |    |    |    |-- rawDescription: string (nullable = true)
#  |    |    |    |-- statusesCount: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- username: string (nullable = true)
#  |    |    |    |-- verified: string (nullable = true)
#  |    |-- outlinks: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- place: struct (nullable = true)
#  |    |    |-- _type: string (nullable = true)
#  |    |    |-- country: string (nullable = true)
#  |    |    |-- countryCode: string (nullable = true)
#  |    |    |-- fullName: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- quoteCount: long (nullable = true)
#  |    |-- quotedTweet: struct (nullable = true)
#  |    |    |-- _type: string (nullable = true)
#  |    |    |-- card: struct (nullable = true)
#  |    |    |    |-- _type: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- thumbnailUrl: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- cashtags: string (nullable = true)
#  |    |    |-- content: string (nullable = true)
#  |    |    |-- conversationId: long (nullable = true)
#  |    |    |-- coordinates: struct (nullable = true)
#  |    |    |    |-- _type: string (nullable = true)
#  |    |    |    |-- latitude: double (nullable = true)
#  |    |    |    |-- longitude: double (nullable = true)
#  |    |    |-- date: string (nullable = true)
#  |    |    |-- hashtags: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- inReplyToTweetId: long (nullable = true)
#  |    |    |-- inReplyToUser: struct (nullable = true)
#  |    |    |    |-- _type: string (nullable = true)
#  |    |    |    |-- created: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- descriptionUrls: string (nullable = true)
#  |    |    |    |-- displayname: string (nullable = true)
#  |    |    |    |-- favouritesCount: long (nullable = true)
#  |    |    |    |-- followersCount: long (nullable = true)
#  |    |    |    |-- friendsCount: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- linkTcourl: string (nullable = true)
#  |    |    |    |-- linkUrl: string (nullable = true)
#  |    |    |    |-- listedCount: long (nullable = true)
#  |    |    |    |-- location: string (nullable = true)
#  |    |    |    |-- mediaCount: long (nullable = true)
#  |    |    |    |-- profileBannerUrl: string (nullable = true)
#  |    |    |    |-- profileImageUrl: string (nullable = true)
#  |    |    |    |-- protected: boolean (nullable = true)
#  |    |    |    |-- rawDescription: string (nullable = true)
#  |    |    |    |-- statusesCount: long (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- username: string (nullable = true)
#  |    |    |    |-- verified: boolean (nullable = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- likeCount: long (nullable = true)
#  |    |    |-- media: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- _type: string (nullable = true)
#  |    |    |    |    |-- duration: double (nullable = true)
#  |    |    |    |    |-- fullUrl: string (nullable = true)
#  |    |    |    |    |-- previewUrl: string (nullable = true)
#  |    |    |    |    |-- thumbnailUrl: string (nullable = true)
#  |    |    |    |    |-- variants: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- _type: string (nullable = true)
#  |    |    |    |    |    |    |-- bitrate: long (nullable = true)
#  |    |    |    |    |    |    |-- contentType: string (nullable = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- views: long (nullable = true)
#  |    |    |-- mentionedUsers: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- _type: string (nullable = true)
#  |    |    |    |    |-- created: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- descriptionUrls: string (nullable = true)
#  |    |    |    |    |-- displayname: string (nullable = true)
#  |    |    |    |    |-- favouritesCount: string (nullable = true)
#  |    |    |    |    |-- followersCount: string (nullable = true)
#  |    |    |    |    |-- friendsCount: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- linkTcourl: string (nullable = true)
#  |    |    |    |    |-- linkUrl: string (nullable = true)
#  |    |    |    |    |-- listedCount: string (nullable = true)
#  |    |    |    |    |-- location: string (nullable = true)
#  |    |    |    |    |-- mediaCount: string (nullable = true)
#  |    |    |    |    |-- profileBannerUrl: string (nullable = true)
#  |    |    |    |    |-- profileImageUrl: string (nullable = true)
#  |    |    |    |    |-- protected: string (nullable = true)
#  |    |    |    |    |-- rawDescription: string (nullable = true)
#  |    |    |    |    |-- statusesCount: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- username: string (nullable = true)
#  |    |    |    |    |-- verified: string (nullable = true)
#  |    |    |-- outlinks: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- place: struct (nullable = true)
#  |    |    |    |-- _type: string (nullable = true)
#  |    |    |    |-- country: string (nullable = true)
#  |    |    |    |-- countryCode: string (nullable = true)
#  |    |    |    |-- fullName: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- quoteCount: long (nullable = true)
#  |    |    |-- quotedTweet: string (nullable = true)
#  |    |    |-- renderedContent: string (nullable = true)
#  |    |    |-- replyCount: long (nullable = true)
#  |    |    |-- retweetCount: long (nullable = true)
#  |    |    |-- retweetedTweet: string (nullable = true)
#  |    |    |-- source: string (nullable = true)
#  |    |    |-- sourceLabel: string (nullable = true)
#  |    |    |-- sourceUrl: string (nullable = true)
#  |    |    |-- tcooutlinks: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- _type: string (nullable = true)
#  |    |    |    |-- created: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- descriptionUrls: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- tcourl: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- displayname: string (nullable = true)
#  |    |    |    |-- favouritesCount: long (nullable = true)
#  |    |    |    |-- followersCount: long (nullable = true)
#  |    |    |    |-- friendsCount: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- label: struct (nullable = true)
#  |    |    |    |    |-- _type: string (nullable = true)
#  |    |    |    |    |-- badgeUrl: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- longDescription: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- linkTcourl: string (nullable = true)
#  |    |    |    |-- linkUrl: string (nullable = true)
#  |    |    |    |-- listedCount: long (nullable = true)
#  |    |    |    |-- location: string (nullable = true)
#  |    |    |    |-- mediaCount: long (nullable = true)
#  |    |    |    |-- profileBannerUrl: string (nullable = true)
#  |    |    |    |-- profileImageUrl: string (nullable = true)
#  |    |    |    |-- protected: boolean (nullable = true)
#  |    |    |    |-- rawDescription: string (nullable = true)
#  |    |    |    |-- statusesCount: long (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- username: string (nullable = true)
#  |    |    |    |-- verified: boolean (nullable = true)
#  |    |-- renderedContent: string (nullable = true)
#  |    |-- replyCount: long (nullable = true)
#  |    |-- retweetCount: long (nullable = true)
#  |    |-- retweetedTweet: string (nullable = true)
#  |    |-- source: string (nullable = true)
#  |    |-- sourceLabel: string (nullable = true)
#  |    |-- sourceUrl: string (nullable = true)
#  |    |-- tcooutlinks: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- url: string (nullable = true)
#  |    |-- user: struct (nullable = true)
#  |    |    |-- _type: string (nullable = true)
#  |    |    |-- created: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- descriptionUrls: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- tcourl: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- displayname: string (nullable = true)
#  |    |    |-- favouritesCount: long (nullable = true)
#  |    |    |-- followersCount: long (nullable = true)
#  |    |    |-- friendsCount: long (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- label: struct (nullable = true)
#  |    |    |    |-- _type: string (nullable = true)
#  |    |    |    |-- badgeUrl: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- longDescription: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- linkTcourl: string (nullable = true)
#  |    |    |-- linkUrl: string (nullable = true)
#  |    |    |-- listedCount: long (nullable = true)
#  |    |    |-- location: string (nullable = true)
#  |    |    |-- mediaCount: long (nullable = true)
#  |    |    |-- profileBannerUrl: string (nullable = true)
#  |    |    |-- profileImageUrl: string (nullable = true)
#  |    |    |-- protected: boolean (nullable = true)
#  |    |    |-- rawDescription: string (nullable = true)
#  |    |    |-- statusesCount: long (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- username: string (nullable = true)
#  |    |    |-- verified: boolean (nullable = true)
#  |-- renderedContent: string (nullable = true)
#  |-- replyCount: long (nullable = true)
#  |-- retweetCount: long (nullable = true)
#  |-- retweetedTweet: string (nullable = true)
#  |-- source: string (nullable = true)
#  |-- sourceLabel: string (nullable = true)
#  |-- sourceUrl: string (nullable = true)
#  |-- tcooutlinks: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- url: string (nullable = true)
#  |-- user: struct (nullable = true)
#  |    |-- _type: string (nullable = true)
#  |    |-- created: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- descriptionUrls: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- tcourl: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- displayname: string (nullable = true)
#  |    |-- favouritesCount: long (nullable = true)
#  |    |-- followersCount: long (nullable = true)
#  |    |-- friendsCount: long (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- label: struct (nullable = true)
#  |    |    |-- _type: string (nullable = true)
#  |    |    |-- badgeUrl: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- longDescription: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- linkTcourl: string (nullable = true)
#  |    |-- linkUrl: string (nullable = true)
#  |    |-- listedCount: long (nullable = true)
#  |    |-- location: string (nullable = true)
#  |    |-- mediaCount: long (nullable = true)
#  |    |-- profileBannerUrl: string (nullable = true)
#  |    |-- profileImageUrl: string (nullable = true)
#  |    |-- protected: boolean (nullable = true)
#  |    |-- rawDescription: string (nullable = true)
#  |    |-- statusesCount: long (nullable = true)
#  |    |-- url: string (nullable = true)
#  |    |-- username: string (nullable = true)
#  |    |-- verified: boolean (nullable = true)

# %%
tweets.show()
# Out:
# +--------------------+--------------------+--------+--------------------+-------------------+-----------+--------------------+--------------------+-------------------+-------------------+--------------------+----+---------+--------------------+--------------------+--------------------+-----+----------+--------------------+--------------------+----------+------------+--------------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+
# |               _type|                card|cashtags|             content|     conversationId|coordinates|                date|            hashtags|                 id|   inReplyToTweetId|       inReplyToUser|lang|likeCount|               media|      mentionedUsers|            outlinks|place|quoteCount|         quotedTweet|     renderedContent|replyCount|retweetCount|retweetedTweet|              source|        sourceLabel|           sourceUrl|         tcooutlinks|                 url|                user|
# +--------------------+--------------------+--------+--------------------+-------------------+-----------+--------------------+--------------------+-------------------+-------------------+--------------------+----+---------+--------------------+--------------------+--------------------+-----+----------+--------------------+--------------------+----------+------------+--------------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+
# |snscrape.modules....|{snscrape.modules...|    null|Africa's Airline ...|1508232397162258434|       null|2022-03-27T23:59:...|                null|1508232397162258434|               null|                null|  en|        0|                null|                null|[https://hubs.li/...| null|         0|                null|Africa's Airline ...|         0|           0|          null|<a href="http://w...|            HubSpot|http://www.hubspo...|[https://t.co/6ae...|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@aangelgarciaa90 ...|1508040825430814728|       null|2022-03-27T23:59:...|                null|1508232396625350662|1508120391625154563|{snscrape.modules...|  es|        0|                null|[{snscrape.module...|                null| null|         0|                null|@aangelgarciaa90 ...|         1|           0|          null|<a href="http://t...|Twitter for Android|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@stevebyrnelive D...|1508184764812996609|       null|2022-03-27T23:59:...|                null|1508232396625260545|1508184764812996609|{snscrape.modules...|  en|        0|                null|[{snscrape.module...|                null| null|         0|                null|@stevebyrnelive D...|         0|           0|          null|<a href="http://t...|Twitter for Android|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@Elsa_Guerra_R @u...|1508229847482572806|       null|2022-03-27T23:59:...|                null|1508232395824242693|1508229847482572806|{snscrape.modules...|  es|        3|                null|[{snscrape.module...|                null| null|         0|                null|@Elsa_Guerra_R @u...|         0|           0|          null|<a href="http://t...| Twitter for iPhone|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|{snscrape.modules...|    null|@MalarkeyIndeed @...|1508129573556428805|       null|2022-03-27T23:59:...|                null|1508232395102769152|1508229180642586624|{snscrape.modules...|  en|        1|                null|[{snscrape.module...|[https://adcmemor...| null|         0|                null|@MalarkeyIndeed @...|         0|           0|          null|<a href="http://t...|Twitter for Android|http://twitter.co...|[https://t.co/WJ2...|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|Slovak 💙💛 for U...|1508232394356281348|       null|2022-03-27T23:59:...|                null|1508232394356281348|               null|                null|  en|        1|                null|                null|[https://twitter....| null|         0|{snscrape.modules...|Slovak 💙💛 for U...|         0|           0|          null|<a href="http://t...| Twitter for iPhone|http://twitter.co...|[https://t.co/gsC...|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|🇷🇺🇺🇦 | #Guerr...|1508232391135043589|       null|2022-03-27T23:59:...|[GuerraRusiaUcran...|1508232391135043589|               null|                null|  es|        0|[{snscrape.module...|                null|                null| null|         0|                null|🇷🇺🇺🇦 | #Guerr...|         0|           0|          null|<a href="http://t...|Twitter for Android|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@ANIABELLO_R Veng...|1508193370706952193|       null|2022-03-27T23:59:...|                null|1508232389595705344|1508193370706952193|{snscrape.modules...|  es|        2|                null|[{snscrape.module...|                null| null|         0|                null|@ANIABELLO_R Veng...|         1|           0|          null|<a href="http://t...|Twitter for Android|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@Ali_Optimale @Ia...|1508165068504018947|       null|2022-03-27T23:59:...|                null|1508232388920324099|1508229282463731715|{snscrape.modules...|  en|        0|                null|[{snscrape.module...|                null| null|         0|                null|@Ali_Optimale @Ia...|         0|           0|          null|<a href="http://t...|Twitter for Android|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@DavidSacks Accep...|1508228379647963138|       null|2022-03-27T23:59:...|                null|1508232388668649476|1508228379647963138|{snscrape.modules...|  en|        0|                null|[{snscrape.module...|                null| null|         0|                null|@DavidSacks Accep...|         0|           0|          null|<a href="http://t...| Twitter for iPhone|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@thoght21 @thehil...|1508231066582237187|       null|2022-03-27T23:59:...|                null|1508232388220006410|1508231648285970437|{snscrape.modules...|  en|        0|                null|[{snscrape.module...|                null| null|         0|                null|@thoght21 @thehil...|         0|           0|          null|<a href="https://...|    Twitter Web App|https://mobile.tw...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@StateDept @POTUS...|1508225592893730816|       null|2022-03-27T23:59:...|                null|1508232387984977922|1508229677034336256|{snscrape.modules...|  en|        0|                null|[{snscrape.module...|                null| null|         0|                null|@StateDept @POTUS...|         0|           0|          null|<a href="http://t...| Twitter for iPhone|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@RobertPszczel Fr...|1508174304550301697|       null|2022-03-27T23:59:...|                null|1508232387360006149|1508174304550301697|{snscrape.modules...|  en|        0|                null|[{snscrape.module...|                null| null|         0|                null|@RobertPszczel Fr...|         0|           0|          null|<a href="http://t...|Twitter for Android|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@Functionalsss @L...|1508214741914640386|       null|2022-03-27T23:59:...|                null|1508232386219192320|1508217768503648259|{snscrape.modules...|  en|        6|                null|[{snscrape.module...|                null| null|         0|                null|@Functionalsss @L...|         1|           0|          null|<a href="http://t...| Twitter for iPhone|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@RockRidgeRocky @...|1508210280639221766|       null|2022-03-27T23:59:...|                null|1508232383048396801|1508216788848418816|{snscrape.modules...|  en|        0|                null|[{snscrape.module...|                null| null|         0|                null|@RockRidgeRocky @...|         0|           0|          null|<a href="https://...|    Twitter Web App|https://mobile.tw...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|{snscrape.modules...|    null|@scythesociety @M...|1508178797987868672|       null|2022-03-27T23:59:...|                null|1508232382175981573|1508231201659789320|{snscrape.modules...|  de|        0|                null|[{snscrape.module...|[https://www.swr....| null|         0|                null|@scythesociety @M...|         1|           0|          null|<a href="http://t...| Twitter for iPhone|http://twitter.co...|[https://t.co/RCC...|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|Wow sleepy Joe sa...|1508232380720496640|       null|2022-03-27T23:59:...|                null|1508232380720496640|               null|                null|  en|        0|                null|                null|[https://twitter....| null|         0|{snscrape.modules...|Wow sleepy Joe sa...|         0|           0|          null|<a href="http://t...| Twitter for iPhone|http://twitter.co...|[https://t.co/dJY...|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@Breaking911 He d...|1508231362444152838|       null|2022-03-27T23:59:...|                null|1508232378736685058|1508231362444152838|{snscrape.modules...|  en|        0|                null|[{snscrape.module...|                null| null|         0|                null|@Breaking911 He d...|         0|           0|          null|<a href="http://t...| Twitter for iPhone|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@Blackey_Masguns ...|1508230816966578178|       null|2022-03-27T23:59:...|                null|1508232374827601923|1508232177514946566|{snscrape.modules...|  en|        1|                null|[{snscrape.module...|                null| null|         0|                null|@Blackey_Masguns ...|         1|           0|          null|<a href="http://t...|Twitter for Android|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@nexta_tv Let's o...|1508030513977638913|       null|2022-03-27T23:59:...|                null|1508232373581889541|1508030513977638913|{snscrape.modules...|  en|        0|                null|[{snscrape.module...|                null| null|         0|                null|@nexta_tv Let's o...|         0|           0|          null|<a href="http://t...|Twitter for Android|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# +--------------------+--------------------+--------+--------------------+-------------------+-----------+--------------------+--------------------+-------------------+-------------------+--------------------+----+---------+--------------------+--------------------+--------------------+-----+----------+--------------------+--------------------+----------+------------+--------------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
#lazy evaluation
tweets.describe()
# Out:
# DataFrame[summary: string, _type: string, content: string, conversationId: string, date: string, id: string, inReplyToTweetId: string, lang: string, likeCount: string, quoteCount: string, renderedContent: string, replyCount: string, retweetCount: string, retweetedTweet: string, source: string, sourceLabel: string, sourceUrl: string, url: string]

# %%
#obteniendo los resultados
tweets.describe().show()
# Out:
# [Stage 5:======================================================>(176 + 1) / 177]
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------+------------------+-------------------+--------------------+------------------+------------------+--------------+--------------------+--------------------+--------------------+--------------------+
# |summary|               _type|             content|      conversationId|                date|                  id|    inReplyToTweetId|   lang|         likeCount|         quoteCount|     renderedContent|        replyCount|      retweetCount|retweetedTweet|              source|         sourceLabel|           sourceUrl|                 url|
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------+------------------+-------------------+--------------------+------------------+------------------+--------------+--------------------+--------------------+--------------------+--------------------+
# |  count|             6798932|             6798932|             6798932|             6798932|             6798932|             3414201|6798932|           6798932|            6798932|             6798932|           6798932|           6798932|             0|             6798932|             6798932|             6798932|             6798932|
# |   mean|                null|              2323.0|1.505154652779525...|                null|1.506089453788396...|1.505432052493300...|   null| 15.87997511962173|0.29767837066174513|              2323.0| 1.251556715084075|3.4970889545593336|          null|                null|2.3424766674698796E7|                null|                null|
# | stddev|                null|                null|2.026188790734632...|                null|1.178682681781409...|1.749949006896926...|   null|452.05482711799107| 10.308039470648927|                null|27.484830449444363| 95.88350218835564|          null|                null|   8217536.208199225|                null|                null|
# |    min|snscrape.modules....|!
#
# FolloW
# RT &amp...|           886944858|2022-03-16T20:44:...| 1504196861082669056|           886944858|     am|                 0|                  0|!
#
# FolloW
# RT &amp...|                 0|                 0|          null|<a href="Http://d...|     AutoTweetNG Pro|  Http://deckvip.com|https://twitter.c...|
# |    max|snscrape.modules....|󠀠
# #StopTheWarInU...| 1508232397162258434|2022-03-27T23:59:...| 1508232397162258434| 1508232177514946566|     zh|            195299|               6410|󠀠
# #StopTheWarInU...|             17595|             42769|          null|<a href="https://...|                  😈|https://zymplify.com|https://twitter.c...|
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------+------------------+-------------------+--------------------+------------------+------------------+--------------+--------------------+--------------------+--------------------+--------------------+

# %%
# %%time
tweets.count()
# Out:
# [Stage 32:=====================================================>(176 + 1) / 177]
# CPU times: user 221 ms, sys: 62.3 ms, total: 284 ms
# Wall time: 3min 13s
# 6798932

# %%
#se puede obtener un objeto "columna", que es como cuando indizamos dataframes, esto regresa una columna
tweets["content"]
# Out:
# Column<'content'>

# %%
tweets.select("content").show(10)
# Out:
# +--------------------+
# |             content|
# +--------------------+
# |Africa's Airline ...|
# |@aangelgarciaa90 ...|
# |@stevebyrnelive D...|
# |@Elsa_Guerra_R @u...|
# |@MalarkeyIndeed @...|
# |Slovak 💙💛 for U...|
# |🇷🇺🇺🇦 | #Guerr...|
# |@ANIABELLO_R Veng...|
# |@Ali_Optimale @Ia...|
# |@DavidSacks Accep...|
# +--------------------+
# only showing top 10 rows

# %%
#pero si se queren ver los resultados, entonces se SELECCIONA la columna, esto regresa un DataFrame
tweets.select("lang").show(10)
# Out:
# +----+
# |lang|
# +----+
# |  en|
# |  es|
# |  en|
# |  es|
# |  en|
# |  en|
# |  es|
# |  es|
# |  en|
# |  en|
# +----+
# only showing top 10 rows

# %%
tweets.filter(tweets.lang == "es").show(10)
# Out:
# [Stage 14:>                                                         (0 + 1) / 1]
# +--------------------+--------------------+--------+--------------------+-------------------+-----------+--------------------+--------------------+-------------------+-------------------+--------------------+----+---------+--------------------+--------------------+--------------------+-----+----------+-----------+--------------------+----------+------------+--------------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+
# |               _type|                card|cashtags|             content|     conversationId|coordinates|                date|            hashtags|                 id|   inReplyToTweetId|       inReplyToUser|lang|likeCount|               media|      mentionedUsers|            outlinks|place|quoteCount|quotedTweet|     renderedContent|replyCount|retweetCount|retweetedTweet|              source|        sourceLabel|           sourceUrl|         tcooutlinks|                 url|                user|
# +--------------------+--------------------+--------+--------------------+-------------------+-----------+--------------------+--------------------+-------------------+-------------------+--------------------+----+---------+--------------------+--------------------+--------------------+-----+----------+-----------+--------------------+----------+------------+--------------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+
# |snscrape.modules....|                null|    null|@aangelgarciaa90 ...|1508040825430814728|       null|2022-03-27T23:59:...|                null|1508232396625350662|1508120391625154563|{snscrape.modules...|  es|        0|                null|[{snscrape.module...|                null| null|         0|       null|@aangelgarciaa90 ...|         1|           0|          null|<a href="http://t...|Twitter for Android|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@Elsa_Guerra_R @u...|1508229847482572806|       null|2022-03-27T23:59:...|                null|1508232395824242693|1508229847482572806|{snscrape.modules...|  es|        3|                null|[{snscrape.module...|                null| null|         0|       null|@Elsa_Guerra_R @u...|         0|           0|          null|<a href="http://t...| Twitter for iPhone|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|🇷🇺🇺🇦 | #Guerr...|1508232391135043589|       null|2022-03-27T23:59:...|[GuerraRusiaUcran...|1508232391135043589|               null|                null|  es|        0|[{snscrape.module...|                null|                null| null|         0|       null|🇷🇺🇺🇦 | #Guerr...|         0|           0|          null|<a href="http://t...|Twitter for Android|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@ANIABELLO_R Veng...|1508193370706952193|       null|2022-03-27T23:59:...|                null|1508232389595705344|1508193370706952193|{snscrape.modules...|  es|        2|                null|[{snscrape.module...|                null| null|         0|       null|@ANIABELLO_R Veng...|         1|           0|          null|<a href="http://t...|Twitter for Android|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@ignacioortelli S...|1508230826831466500|       null|2022-03-27T23:59:...|                null|1508232371723636736|1508230826831466500|{snscrape.modules...|  es|        0|                null|[{snscrape.module...|                null| null|         0|       null|@ignacioortelli S...|         0|           0|          null|<a href="http://t...| Twitter for iPhone|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@Guaricongo @Otro...|1507992201023873028|       null|2022-03-27T23:59:...|                null|1508232362571796482|1508230348911616009|{snscrape.modules...|  es|        2|                null|[{snscrape.module...|                null| null|         0|       null|@Guaricongo @Otro...|         0|           0|          null|<a href="http://t...| Twitter for iPhone|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|Como CODA le quit...|1508232353340088328|       null|2022-03-27T23:59:...|                null|1508232353340088328|               null|                null|  es|        0|                null|                null|                null| null|         0|       null|Como CODA le quit...|         0|           0|          null|<a href="http://t...|Twitter for Android|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|{snscrape.modules...|    null|Clave
# Ucrania: c...|1508232348986273796|       null|2022-03-27T23:59:...|                null|1508232348986273796|               null|                null|  es|        0|                null|[{snscrape.module...|[https://www.laiz...| null|         0|       null|Clave
# Ucrania: c...|         0|           0|          null|<a href="http://t...|Twitter for Android|http://twitter.co...|[https://t.co/guM...|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|T-72B3 ruso, el B...|1508232343642906627|       null|2022-03-27T23:59:...|                null|1508232343642906627|               null|                null|  es|        0|[{snscrape.module...|                null|                null| null|         0|       null|T-72B3 ruso, el B...|         0|           0|          null|<a href="http://t...|Twitter for Android|http://twitter.co...|                null|https://twitter.c...|{snscrape.modules...|
# |snscrape.modules....|                null|    null|@PoleoRafael Buen...|1508163215599022094|       null|2022-03-27T23:59:...|                null|1508232337733132295|1508163215599022094|{snscrape.modules...|  es|        0|                null|[{snscrape.module...|                null| null|         0|       null|@PoleoRafael Buen...|         0|           0|          null|<a href="https://...|    Twitter Web App|https://mobile.tw...|                null|https://twitter.c...|{snscrape.modules...|
# +--------------------+--------------------+--------+--------------------+-------------------+-----------+--------------------+--------------------+-------------------+-------------------+--------------------+----+---------+--------------------+--------------------+--------------------+-----+----------+-----------+--------------------+----------+------------+--------------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 10 rows

# %%
tweets.select("user")
# Out:
# DataFrame[user: struct<_type:string,created:string,description:string,descriptionUrls:array<struct<indices:array<bigint>,tcourl:string,text:string,url:string>>,displayname:string,favouritesCount:bigint,followersCount:bigint,friendsCount:bigint,id:bigint,label:struct<_type:string,badgeUrl:string,description:string,longDescription:string,url:string>,linkTcourl:string,linkUrl:string,listedCount:bigint,location:string,mediaCount:bigint,profileBannerUrl:string,profileImageUrl:string,protected:boolean,rawDescription:string,statusesCount:bigint,url:string,username:string,verified:boolean>]

# %%
tweets.select("user.created").show(10)
# Out:
# +--------------------+
# |             created|
# +--------------------+
# |2011-09-17T00:58:...|
# |2018-07-15T08:39:...|
# |2010-08-20T03:45:...|
# |2011-06-21T03:18:...|
# |2009-09-23T15:17:...|
# |2012-01-19T16:34:...|
# |2016-07-17T08:56:...|
# |2021-09-01T00:41:...|
# |2015-03-11T13:41:...|
# |2019-06-11T17:06:...|
# +--------------------+
# only showing top 10 rows

# %%
#seleccionando múltiples usuarios
tweets.select(["user.displayname", "user.description"]).show(10)
# Out:
# +--------------------+--------------------+
# |         displayname|         description|
# +--------------------+--------------------+
# |               Skift|Breaking news, in...|
# |       Kwondeu♥️💛💜|Portugal, Francia...|
# |            Tralfraz|Still trying to f...|
# |  Edgar Vega Suriaga|Universidad Andin...|
# |     Derisive One 🏴|“The World is my ...|
# |        Amy M. Wicks|Carbs, cocktails,...|
# |  En Vivo - Noticias|Cubrimiento espec...|
# |              Sergio|Amante de la natu...|
# |Giedrius Cikanavi...|                    |
# |       David Dickson|Space Resources p...|
# +--------------------+--------------------+
# only showing top 10 rows

# %%
#Existe entonces SPARK SQL, que puede manejar los dataframes como si fuera SQL
tweets.createOrReplaceTempView("war_tweets")

# %%
spark.sql("SELECT user.displayname, user.description FROM war_tweets").show(10)
# Out:
# +--------------------+--------------------+
# |         displayname|         description|
# +--------------------+--------------------+
# |               Skift|Breaking news, in...|
# |       Kwondeu♥️💛💜|Portugal, Francia...|
# |            Tralfraz|Still trying to f...|
# |  Edgar Vega Suriaga|Universidad Andin...|
# |     Derisive One 🏴|“The World is my ...|
# |        Amy M. Wicks|Carbs, cocktails,...|
# |  En Vivo - Noticias|Cubrimiento espec...|
# |              Sergio|Amante de la natu...|
# |Giedrius Cikanavi...|                    |
# |       David Dickson|Space Resources p...|
# +--------------------+--------------------+
# only showing top 10 rows

# %%
#ahora una con where
spark.sql("SELECT count(*) from war_tweets where retweetCount > 100").show()
# Out:
# [Stage 16:=====================================================>(176 + 1) / 177]
# +--------+
# |count(1)|
# +--------+
# |   30147|
# +--------+

# %%
tweets.filter(tweets.retweetCount > 100).count()
# Out:
# 30147

# %%
#otra manera
tweets.filter("retweetCount > 100").count()
# Out:
# 30147

# %%
tweets.groupBy("user.id").sum("retweetCount").show()
# Out:
# [Stage 25:>                                                         (0 + 1) / 1]
# +----------+-----------------+
# |        id|sum(retweetCount)|
# +----------+-----------------+
# |3859068195|               51|
# |1872759138|                0|
# |  21056056|                1|
# |2247960367|                1|
# |2440523790|                9|
# | 469323640|                0|
# | 271597395|               53|
# |   6519522|              126|
# | 419133954|               20|
# |3372876645|                2|
# | 472201774|                2|
# |   8275012|                0|
# | 636311847|                0|
# | 192336675|                0|
# | 150783792|                7|
# |3430448104|                0|
# |2874866717|               23|
# |1286880216|                0|
# |2560184623|                0|
# | 858202051|                8|
# +----------+-----------------+
# only showing top 20 rows

# %%
# %%time
from pyspark.sql.functions import sum as _sum
from pyspark.sql.functions import avg as _avg
from pyspark.sql.functions import count as _count
from pyspark.sql.functions import col 

tweets.groupby("user.id") \
    .agg(_count("user.id").alias("total_tweets"),
        _sum("retweetCount").alias("total_retweets"),
         _avg("retweetCount").alias("avg_retweets")) \
    .where( (col("avg_retweets") >= 100) & (col("total_tweets") > 30)).show()
         #(df.state  == "OH") & (df.gender  == "M")
# Out:
# [Stage 31:>                                                         (0 + 1) / 1]
# +-------------------+------------+--------------+------------------+
# |                 id|total_tweets|total_retweets|      avg_retweets|
# +-------------------+------------+--------------+------------------+
# | 946018506268700672|          55|         14064|255.70909090909092|
# | 818893114979061761|          57|         21977|385.56140350877195|
# |           14293310|         111|         11959|107.73873873873873|
# |           17384585|          60|         10073|167.88333333333333|
# |          314587185|          63|         12635|200.55555555555554|
# |          459872442|          83|         18341|220.97590361445782|
# |         2467139606|          34|          9308| 273.7647058823529|
# |             742143|         144|         42473| 294.9513888888889|
# |          153170209|          86|          8957|104.15116279069767|
# |           14135350|          64|         17174|         268.34375|
# |          613212190|          35|          7414|211.82857142857142|
# |          105327432|         116|         60271| 519.5775862068965|
# |           23554832|          41|          5537| 135.0487804878049|
# | 821894639284355076|         121|         22056|182.28099173553719|
# |           18025377|          80|         12309|          153.8625|
# | 943906396180905984|         107|         15408|             144.0|
# |          535643852|          46|         14564|316.60869565217394|
# |          143427448|          98|         72369| 738.4591836734694|
# |1457867047334031360|          37|         16252| 439.2432432432432|
# |          454099919|         147|        222741|1515.2448979591836|
# +-------------------+------------+--------------+------------------+
# only showing top 20 rows
#
# CPU times: user 225 ms, sys: 71.7 ms, total: 297 ms
# Wall time: 3min 59s

# %%
spark.sql("""
            select * from 
            (
                select user.id, count(*) as total_tweets, sum(retweetCount) as total_retweets, avg(retweetCount) as avg_retweets
                from war_tweets
                group by user.id 
            ) as s
            where s.avg_retweets >= 100 and s.total_retweets > 30
            """).show()
# Out:
# [Stage 24:>                                                         (0 + 1) / 1]
# +-------------------+------------+--------------+------------------+
# |                 id|total_tweets|total_retweets|      avg_retweets|
# +-------------------+------------+--------------+------------------+
# |1399468386183172097|           1|           117|             117.0|
# |1329493178416721920|           3|          1747| 582.3333333333334|
# | 946018506268700672|          55|         14064|255.70909090909092|
# |1486369615487852547|           1|           151|             151.0|
# |1083551928821448710|           5|           957|             191.4|
# |1238583088998830081|          21|         24048| 1145.142857142857|
# |          277587469|          56|         14447|257.98214285714283|
# |           22771961|          10|          6364|             636.4|
# |         3028689160|           1|           118|             118.0|
# |1088371662108676096|           5|          4963|             992.6|
# |1430211561491206147|          30|          7238|241.26666666666668|
# |           16193763|           3|           322|107.33333333333333|
# |         3044772544|          38|         16429| 432.3421052631579|
# |             807095|         204|         53963|264.52450980392155|
# |           17384585|          60|         10073|167.88333333333333|
# |          314587185|          63|         12635|200.55555555555554|
# |          175248804|         186|         22572|121.35483870967742|
# | 993137216309383169|           2|          1363|             681.5|
# |         2986275514|           7|          1429|204.14285714285714|
# |1032296549286666240|           2|           496|             248.0|
# +-------------------+------------+--------------+------------------+
# only showing top 20 rows

# %%
#fechas
from pyspark.sql.functions import (dayofmonth, hour,  
                                   dayofyear, month, year,
                                   weekofyear, 
                                   format_number,
                                   date_format, datediff, current_date)
tweets.select(['date', \
               dayofmonth(tweets['date']), \
               hour(tweets['date']), \
               month(tweets['date']), \
               year(tweets['date']), \
               weekofyear(tweets['date'])]).show()
# Out:
# +--------------------+----------------+----------+-----------+----------+----------------+
# |                date|dayofmonth(date)|hour(date)|month(date)|year(date)|weekofyear(date)|
# +--------------------+----------------+----------+-----------+----------+----------------+
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# |2022-03-27T23:59:...|              27|        23|          3|      2022|              12|
# +--------------------+----------------+----------+-----------+----------+----------------+
# only showing top 20 rows

# %%
#https://sparkbyexamples.com/pyspark/pyspark-sql-date-and-timestamp-functions/

tweets.select('user.created', current_date().alias("current_date"), datediff(current_date(), tweets["user.created"]).alias("difference")).show()
# Out:
# +--------------------+------------+----------+
# |             created|current_date|difference|
# +--------------------+------------+----------+
# |2011-09-17T00:58:...|  2022-04-14|      3862|
# |2018-07-15T08:39:...|  2022-04-14|      1369|
# |2010-08-20T03:45:...|  2022-04-14|      4255|
# |2011-06-21T03:18:...|  2022-04-14|      3950|
# |2009-09-23T15:17:...|  2022-04-14|      4586|
# |2012-01-19T16:34:...|  2022-04-14|      3738|
# |2016-07-17T08:56:...|  2022-04-14|      2097|
# |2021-09-01T00:41:...|  2022-04-14|       225|
# |2015-03-11T13:41:...|  2022-04-14|      2591|
# |2019-06-11T17:06:...|  2022-04-14|      1038|
# |2014-09-16T03:53:...|  2022-04-14|      2767|
# |2017-03-27T14:33:...|  2022-04-14|      1844|
# |2019-12-11T07:36:...|  2022-04-14|       855|
# |2009-07-01T23:59:...|  2022-04-14|      4670|
# |2020-03-10T14:20:...|  2022-04-14|       765|
# |2022-03-20T20:52:...|  2022-04-14|        25|
# |2012-07-31T18:53:...|  2022-04-14|      3544|
# |2014-11-22T16:30:...|  2022-04-14|      2700|
# |2020-05-20T14:23:...|  2022-04-14|       694|
# |2021-04-08T13:33:...|  2022-04-14|       371|
# +--------------------+------------+----------+
# only showing top 20 rows

# %%
#en años
tweets.select('user.created', current_date().alias("current_date"), (datediff(current_date(), tweets["user.created"])/365.25).alias("difference")).show()
# Out:
# +--------------------+------------+-------------------+
# |             created|current_date|         difference|
# +--------------------+------------+-------------------+
# |2011-09-17T00:58:...|  2022-04-14| 10.573579739904176|
# |2018-07-15T08:39:...|  2022-04-14| 3.7481177275838466|
# |2010-08-20T03:45:...|  2022-04-14| 11.649555099247092|
# |2011-06-21T03:18:...|  2022-04-14|   10.8145106091718|
# |2009-09-23T15:17:...|  2022-04-14| 12.555783709787816|
# |2012-01-19T16:34:...|  2022-04-14| 10.234086242299794|
# |2016-07-17T08:56:...|  2022-04-14| 5.7412731006160165|
# |2021-09-01T00:41:...|  2022-04-14| 0.6160164271047228|
# |2015-03-11T13:41:...|  2022-04-14|  7.093771389459275|
# |2019-06-11T17:06:...|  2022-04-14|  2.841889117043121|
# |2014-09-16T03:53:...|  2022-04-14|  7.575633127994524|
# |2017-03-27T14:33:...|  2022-04-14|  5.048596851471594|
# |2019-12-11T07:36:...|  2022-04-14| 2.3408624229979464|
# |2009-07-01T23:59:...|  2022-04-14| 12.785763175906913|
# |2020-03-10T14:20:...|  2022-04-14| 2.0944558521560577|
# |2022-03-20T20:52:...|  2022-04-14|0.06844626967830253|
# |2012-07-31T18:53:...|  2022-04-14|  9.702943189596168|
# |2014-11-22T16:30:...|  2022-04-14|  7.392197125256674|
# |2020-05-20T14:23:...|  2022-04-14| 1.9000684462696784|
# |2021-04-08T13:33:...|  2022-04-14| 1.0157426420260096|
# +--------------------+------------+-------------------+
# only showing top 20 rows

# %%
#ejemplos
#ttps://sparkbyexamples.com/

#documentación SPARK
#ttps://spark.apache.org/docs/

# %% [markdown]
# ## Tarea:
#
# *    Obtener la fecha mínima y la fecha máxima disponible en el dataset
# *    Obtener el usuario ('display name' requerido) más popular el día 27 de marzo
# *    Obtener los hashtagas más populares, además de "Putin" "Ucrania" y "Ukraine" (**Bonus:** hacer un gráfico de barras con el top 10)
# *    ¿Cuántos usuarios tienen tweets repetidos?

# %% [markdown]
# # **LA LINEA MÁS IMPORTANTE DE TODO EL CÓDIGO!!!!!!**

# %%
spark.stop()
