# %%
from pyspark.sql import SparkSession
from datetime import datetime

# %%
warehouse_location = '/user/carpetas_inv'

# %%
# !hdfs dfs -ls /user
# !hdfs dfs -mkdir /user/carpetas_inv
# !wget https://storage.googleapis.com/public-bucket-up-2022/carpetas_investigacion.csv
# !hdfs dfs -moveFromLocal carpetas_investigacion.csv /user/carpetas_inv/

# %%
#en hive, crear tabla como externa.
"""
hive>
CREATE EXTERNAL TABLE carpetas_investigacion
(
  id INT ,
  ao_hechos INT,
  mes_hechos STRING,
  fecha_hechos TIMESTAMP,
  delito STRING,
  categoria_delito STRING,
  fiscalia STRING ,
  agencia STRING ,
  unidad_investigacion STRING,
  colonia_hechos STRING ,
  alcaldia_hechos STRING,
  fecha_inicio TIMESTAMP ,
  mes_inicio STRING,
  ao_inicio INT,
  calle_hechos STRING ,
  calle_hechos2 STRING,
  longitud float,
  latitud float,
  geopoint STRING  
)
ROW FORMAT DELIMITED
FIELDS TERMINATED BY ','
LINES TERMINATED BY '\n'
STORED AS TEXTFILE
location '/user/carpetas_inv';
"""
# Out:
# "\nhive>\nCREATE EXTERNAL TABLE carpetas_investigacion\n(\n  id INT ,\n  ao_hechos INT,\n  mes_hechos STRING,\n  fecha_hechos TIMESTAMP,\n  delito STRING,\n  categoria_delito STRING,\n  fiscalia STRING ,\n  agencia STRING ,\n  unidad_investigacion STRING,\n  colonia_hechos STRING ,\n  alcaldia_hechos STRING,\n  fecha_inicio TIMESTAMP ,\n  mes_inicio STRING,\n  ao_inicio INT,\n  calle_hechos STRING ,\n  calle_hechos2 STRING,\n  longitud float,\n  latitud float,\n  geopoint STRING  \n)\nROW FORMAT DELIMITED\nFIELDS TERMINATED BY ','\nLINES TERMINATED BY '\n'\nSTORED AS TEXTFILE\nlocation '/user/carpetas_inv';\n"

# %%
spark = SparkSession \
    .builder \
    .appName("Mi primer app de Spark") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .enableHiveSupport() \
    .getOrCreate()
# Out:
# 22/04/18 18:43:03 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 22/04/18 18:43:03 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 22/04/18 18:43:03 INFO org.apache.spark.SparkEnv: Registering BlockManagerMasterHeartbeat
# 22/04/18 18:43:03 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator

# %%
spark.sql("SELECT * FROM carpetas_investigacion limit 10").show()
# Out:
# ivysettings.xml file not found in HIVE_HOME or HIVE_CONF_DIR,/etc/hive/conf.dist/ivysettings.xml will be used
# [Stage 0:====================================================>      (8 + 0) / 9]
# +----+---------+----------+-------------------+--------------------+--------------------+--------------------+-------+--------------------+--------------------+-------------------+-------------------+----------+---------+--------------------+--------------------+----------+---------+--------------+
# |  id|ao_hechos|mes_hechos|       fecha_hechos|              delito|    categoria_delito|            fiscalia|agencia|unidad_investigacion|      colonia_hechos|    alcaldia_hechos|       fecha_inicio|mes_inicio|ao_inicio|        calle_hechos|       calle_hechos2|  longitud|  latitud|      geopoint|
# +----+---------+----------+-------------------+--------------------+--------------------+--------------------+-------+--------------------+--------------------+-------------------+-------------------+----------+---------+--------------------+--------------------+----------+---------+--------------+
# |null|     null|mes_hechos|               null|              delito|    categoria_delito|            fiscalia|agencia|unidad_investigacion|      colonia_hechos|    alcaldia_hechos|               null|mes_inicio|     null|        calle_hechos|       calle_hechos2|      null|     null|      geopoint|
# |   0|     2016|     Enero|2016-01-05 17:00:00|   LESIONES CULPOSAS|DELITO DE BAJO IM...|INVESTIGACIÓN EN ...|  GAM-6|              UI-1CD|    GRANJAS MODERNAS|   GUSTAVO A MADERO|2016-01-05 18:35:37|     Enero|     2016|  SAN JUAN DE ARAGON|         CALLE ANZAR| -99.10352|19.481075|"19.4810759998|
# |   1|     2017| Noviembre|2017-11-01 14:00:00|ROBO DE VEHICULO ...|ROBO DE VEHÍCULO ...|INVESTIGACIÓN EN ...|   AZ-1|              UI-1SD|                    |TLALNEPANTLA DE BAZ|2017-11-01 16:45:20| Noviembre|     2017|       BENITO JUAREZ|"MUNICIPIO DE TLA...|      null|     null|              |
# |   2|     2017| Noviembre|2017-11-01 16:40:00|ROBO A TRANSEUNTE...|ROBO A TRANSEUNTE...|INVESTIGACIÓN EN ...|  IZC-2|              UI-1SD|GABRIEL RAMOS MIL...|          IZTACALCO|2017-11-01 16:56:04| Noviembre|     2017|             SUR 117|        ORIENTE 100A| -99.10607|19.395397|"19.3953976727|
# |   3|     2015| Diciembre|2015-12-30 20:00:00|              FRAUDE|DELITO DE BAJO IM...|INVESTIGACIÓN EN ...|  IZP-8|              UI-1CD|CONSEJO AGRARISTA...|         IZTAPALAPA|2016-01-05 21:12:42|     Enero|     2016|CUARTA CERRADA DE...|ENCINO (SIN REGIS...|-99.055885|19.322458|"19.3224579998|
# |   4|     2018|      Mayo|2018-05-16 16:00:00|ROBO A REPARTIDOR...|ROBO A REPARTIDOR...|INVESTIGACIÓN EN ...|  IZP-9|              UI-2SD|DESARROLLO URBANO...|         IZTAPALAPA|2018-05-22 10:44:45|      Mayo|     2018|             TARASCO|            ZAPOTECO|-99.042786|19.319141|"19.3191405147|
# |   5|     2018|      Mayo|2018-05-21 20:40:00|ROBO A TRANSEUNTE...|DELITO DE BAJO IM...|INVESTIGACIÓN EN ...|  CUH-2|              UI-2SD| INFONAVIT IZTACALCO|          IZTACALCO|2018-05-22 10:52:18|      Mayo|     2018|FRANCISCO DEL PAS...|                ISLA|-99.111565|19.386595|"19.3865939284|
# |   6|     2018|      Mayo|2018-05-22 06:20:00|ROBO A TRANSEUNTE...|DELITO DE BAJO IM...|INVESTIGACIÓN EN ...|   BJ-1|              UI-1SD|      TLACOQUEMECATL|      BENITO JUAREZ|2018-05-22 11:09:00|      Mayo|     2018|AV. DE LOS INSURG...|                    |  -99.1771|19.379581|"19.3795809108|
# |   7|     2016|     Enero|2016-01-02 21:20:00|      ROBO DE DINERO|DELITO DE BAJO IM...|INVESTIGACIÓN EN ...|  IZC-1|              UI-1CD|           LOS REYES|          IZTACALCO|2016-01-05 19:37:09|     Enero|     2016|AV PLUTARCO ELIAS...|         MIRAFUENTES| -99.11718| 19.39804|"19.3980399998|
# |   8|     2017| Noviembre|2017-11-01 17:15:00|LESIONES INTENCIO...|DELITO DE BAJO IM...|INVESTIGACIÓN EN ...| STCMZV|              UI-1CD|              CENTRO|         CUAUHTEMOC|2017-11-01 18:48:18| Noviembre|     2017|PLAZA DE LA CONST...|         PINO SUAREZ| -99.13245|19.431791|"19.4317911274|
# +----+---------+----------+-------------------+--------------------+--------------------+--------------------+-------+--------------------+--------------------+-------------------+-------------------+----------+---------+--------------------+--------------------+----------+---------+--------------+

# %%
ubicaciones = spark.sql("SELECT delito, fecha_hechos, fiscalia, latitud, longitud FROM carpetas_investigacion where alcaldia_hechos = 'TLALPAN' and latitud is not null")

# %%
ubicaciones
# Out:
# DataFrame[delito: string, fecha_hechos: timestamp, fiscalia: string, latitud: float, longitud: float]

# %%
ubicaciones.show()
# Out:
# +--------------------+-------------------+--------------------+---------+----------+
# |              delito|       fecha_hechos|            fiscalia|  latitud|  longitud|
# +--------------------+-------------------+--------------------+---------+----------+
# |ROBO A NEGOCIO SI...|2016-01-05 15:10:00|INVESTIGACIÓN EN ...|19.289762| -99.17881|
# |ROBO DE ACCESORIO...|2018-05-22 20:30:00|INVESTIGACIÓN EN ...|19.281824| -99.17947|
# |ROBO DE VEHICULO ...|2018-05-14 12:00:00|INVESTIGACIÓN EN ...|19.288815| -99.22349|
# |FALSIFICACION DE ...|2018-05-19 11:00:00|INVESTIGACIÓN EN ...| 19.29802| -99.13836|
# |     ROBO DE OBJETOS|2016-01-15 07:20:00|INVESTIGACIÓN EN ...|19.285206|-99.218414|
# |ROBO A CASA HABIT...|2015-01-14 15:00:00|INVESTIGACIÓN EN ...|19.264786|-99.207695|
# |ROBO DE OBJETOS D...|2018-05-27 10:30:00|INVESTIGACIÓN EN ...|19.291553| -99.16226|
# |  VIOLENCIA FAMILIAR|2018-05-27 03:00:00|INVESTIGACIÓN EN ...|19.267105| -99.23836|
# |   LESIONES CULPOSAS|2015-06-18 00:00:00|INVESTIGACIÓN EN ...|19.280169| -99.16629|
# |CONTRA FUNCIONARI...|2016-03-30 00:45:00|INVESTIGACIÓN EN ...|19.293398| -99.15803|
# |  ABUSO DE CONFIANZA|2015-11-08 21:00:00|INVESTIGACIÓN EN ...|19.285606| -99.22572|
# |              FRAUDE|2016-02-05 14:00:00|INVESTIGACIÓN EN ...|19.294977| -99.12854|
# |LESIONES CULPOSAS...|2017-10-30 18:00:00|INVESTIGACIÓN EN ...|19.270365| -99.24129|
# |  VIOLENCIA FAMILIAR|2017-10-26 11:00:00|INVESTIGACIÓN EN ...|19.265541| -99.16788|
# |ROBO A TRANSEUNTE...|2018-01-25 11:30:00|INVESTIGACIÓN EN ...|19.293272| -99.15227|
# |            AMENAZAS|2018-01-23 18:00:00|INVESTIGACIÓN EN ...|19.282726|  -99.2054|
# |FALSIFICACION DE ...|2016-03-23 19:52:00|INVESTIGACIÓN EN ...| 19.30368| -99.12438|
# |  DENUNCIA DE HECHOS|2017-12-14 09:05:00|INVESTIGACIÓN EN ...| 19.29032| -99.21736|
# |              FRAUDE|2017-04-30 12:00:00|INVESTIGACIÓN PAR...|19.295399| -99.18407|
# |  ROBO DE DOCUMENTOS|2018-01-22 07:48:00|INVESTIGACIÓN EN ...|19.293941|-99.157234|
# +--------------------+-------------------+--------------------+---------+----------+
# only showing top 20 rows

# %%
ubicaciones.printSchema()
# Out:
# root
#  |-- delito: string (nullable = true)
#  |-- fecha_hechos: timestamp (nullable = true)
#  |-- fiscalia: string (nullable = true)
#  |-- latitud: float (nullable = true)
#  |-- longitud: float (nullable = true)

# %%
ubic_pandas = ubicaciones.toPandas()

# %%
ubic_pandas
# Out:
#                                                   delito        fecha_hechos  \
# 0                           ROBO A NEGOCIO SIN VIOLENCIA 2016-01-05 15:10:00
# 1                             ROBO DE ACCESORIOS DE AUTO 2018-05-22 20:30:00
# 2      ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VI... 2018-05-14 12:00:00
# 3      FALSIFICACION DE TITULOS AL PORTADOR Y DOCUMEN... 2018-05-19 11:00:00
# 4                                        ROBO DE OBJETOS 2016-01-15 07:20:00
# ...                                                  ...                 ...
# 43507                          QUEBRANTAMIENTO DE SELLOS 2018-04-03 09:00:00
# 43508                         ROBO DE ACCESORIOS DE AUTO 2017-09-21 07:00:00
# 43509  ROBO A PASAJERO / CONDUCTOR DE TAXI CON VIOLENCIA 2018-07-09 20:00:00
# 43510                                           AMENAZAS 2018-07-26 12:00:00
# 43511  ROBO DE VEHICULO DE SERVICIO PARTICULAR CON VI... 2018-07-09 19:30:00
#
#                                                 fiscalia    latitud   longitud
# 0                               INVESTIGACIÓN EN TLALPAN  19.289762 -99.178810
# 1                               INVESTIGACIÓN EN TLALPAN  19.281824 -99.179466
# 2                               INVESTIGACIÓN EN TLALPAN  19.288815 -99.223488
# 3                               INVESTIGACIÓN EN TLALPAN  19.298019 -99.138359
# 4                               INVESTIGACIÓN EN TLALPAN  19.285206 -99.218414
# ...                                                  ...        ...        ...
# 43507  INVESTIGACIÓN EN DELITOS AMBIENTALES Y EN MATE...  19.285286 -99.128784
# 43508                           INVESTIGACIÓN EN TLALPAN  19.210995 -99.200905
# 43509                          INVESTIGACIÓN EN COYOACÁN  19.221430 -99.210609
# 43510                           INVESTIGACIÓN EN TLALPAN  19.214911 -99.177666
# 43511                           INVESTIGACIÓN EN TLALPAN  19.217144 -99.213737
#
# [43512 rows x 5 columns]

# %%
ubic_pandas = ubic_pandas[ubic_pandas["fecha_hechos"].apply(lambda x: x.year == 2018)]

# %%
import folium as fl
import pandas as pd
import numpy as np

# %%
m = fl.Map(
    location = [19.425665, -99.154586],
    zoom_start = 14,
)

# %%
counter = 0
for i in ubic_pandas.index:    
    if ~np.isnan(ubic_pandas.latitud[i]) and ~np.isnan(ubic_pandas.longitud[i]):
        #print(ubic_pandas.loc[i, "longitud"], ~np.isnan(ubic_pandas.longitud[i]))
        fl.Marker([ubic_pandas.loc[i, "latitud"], ubic_pandas.loc[i, "longitud"] ] ).add_to(m)
    counter += 1
    if counter > 100:
        break

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e3934eefaed542f6a6df084b61a9ea1e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e3934eefaed542f6a6df084b61a9ea1e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e3934eefaed542f6a6df084b61a9ea1e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e3934eefaed542f6a6df084b61a9ea1e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B19.425665%2C%20-99.154586%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
#Getting flashy
ubic_pandas.shape
# Out:
# (13486, 5)

# %%
m1 = fl.Map(
    location = [19.425665, -99.154586],
    zoom_start = 14,
)

counter = 0
for i in ubic_pandas.index:
    if ~np.isnan(ubic_pandas.latitud[i]) and ~np.isnan(ubic_pandas.longitud[i]):  
        if ubic_pandas.loc[i, "fiscalia"].strip() != "INVESTIGACIÓN EN TLALPAN":
            fl.Marker(
                location = [ubic_pandas.loc[i, "latitud"], ubic_pandas.loc[i, "longitud"] ],
                popup = ubic_pandas.loc[i, "delito"], clustered_marker = True        
            ).add_to(m1)
        else:
            fl.Marker(
                location = [ubic_pandas.loc[i, "latitud"], ubic_pandas.loc[i, "longitud"] ],
                popup = ubic_pandas.loc[i, "delito"],
                icon = fl.Icon(color="red", icon="info-sign"), clustered_marker = True
            ).add_to(m1)
    counter += 1
    if counter > 100:
        break

# %%
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_09d0ddcb82c84dc8929065d2b4bd4a6c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_09d0ddcb82c84dc8929065d2b4bd4a6c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_09d0ddcb82c84dc8929065d2b4bd4a6c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_09d0ddcb82c84dc8929065d2b4bd4a6c%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B19.425665%2C%20-99.154586%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
#otros ejemplos
#https://python-visualization.github.io/folium/quickstart.html

# %%
spark.stop()
