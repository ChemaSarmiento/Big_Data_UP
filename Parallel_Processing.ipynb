# %%
import multiprocessing as mp
import os
import linecache
from functools import partial
print("Procesadores: {}".format(mp.cpu_count()))
# Out:
# Procesadores: 2

# %% [markdown]
# Montar Drive, copiar archivo a la maquina local de colaboratory

# %%
# !cp /content/drive/MyDrive/BigData/checkouts_seattle.zip .
# Out:
# cp: cannot stat '/content/drive/MyDrive/BigData/checkouts_seattle.zip': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Descomprimir

# %%
# !unzip drive/MyDrive/BigData/checkouts_seattle.zip
# Out:
# Archive:  drive/MyDrive/BigData/checkouts_seattle.zip
#   inflating: Checkouts by Title FAQs.pdf
#   inflating: checkouts-by-title.csv
#   inflating: socrata_metadata.json

# %% [markdown]
# Lista de archivos con detalle (El h en -lh significa "human", para leer el tamaño de los archivos en KB, MB, GB... y no en bytes)

# %%
ls -lh
# Out:
# total 7.2G
# -rw-r--r-- 1 root root 7.2G Dec  3  2019  checkouts-by-title.csv
# -rw-r--r-- 1 root root 363K Dec  3  2019 'Checkouts by Title FAQs.pdf'
# drwx------ 6 root root 4.0K Apr  1 19:14  drive/
# drwxr-xr-x 1 root root 4.0K Mar 23 14:22  sample_data/
# -rw-r--r-- 1 root root  16K Dec  3  2019  socrata_metadata.json

# %% [markdown]
# Encabezado de archivo

# %%
# !tail checkouts-by-title.csv
# Out:
# Physical,Horizon,BOOK,2014,8,6,Fueled for adventure / adapted by Christine Peymani and Adam B. Murr ; illustrated by Carson Van Osten.,"Peymani, Christine","Automobiles Juvenile fiction, Automobile racing Juvenile fiction, Movie novels","Golden Books,",c2011.
# Digital,OverDrive,EBOOK,2014,8,1,Why God Won't Go Away: Brain Science and the Biology of Belief,"Andrew Newberg, M.D.","Nonfiction, Religion & Spirituality, Science","Random House, Inc.",2012
# Digital,OverDrive,EBOOK,2014,8,2,Criss Cross,Lynne Rae Perkins,"Historical Fiction, Young Adult Fiction",HarperCollins Publishers Inc.,2010
# Physical,Horizon,BOOK,2014,8,1,The woman who shot Mussolini / Frances Stonor Saunders.,"Saunders, Frances Stonor","Gibson Violet, Mussolini Benito 1883 1945 Assassination attempt 1926 April 7, Assassins Biography, Catholic converts Biography, Aristocracy Social class Ireland Dublin Biography, Ashbourne Edward Gibson Baron 1837 1913 Family, Ireland History 1837 1901 Biography, Dublin Ireland Biography, Mussolini Benito 1883 1945, Fascism Italy History 20th century","Metropolitan Books/Henry Holt and Co.,",2010.
# Physical,Horizon,BOOK,2014,8,1,The people's king : the true story of the abdication / Susan Williams.,"Williams, A. Susan","Windsor Edward Duke of 1894 1972, Windsor Edward Duke of 1894 1972 Abdication 1936, Great Britain Kings and rulers Biography, Great Britain History Edward VIII 1936","Palgrave Macmillan,",2004.
# Physical,Horizon,BOOK,2014,8,2,Girls to the front : the true story of the Riot grrrl revolution / Sara Marcus.,"Marcus, Sara, 1977-","Riot grrrl movement United States History, Feminism United States History 20th century","HarperPerennial,",c2010.
# Physical,Horizon,SOUNDDISC,2014,8,1,"Alfred, Lord Tennyson [sound recording].","Tennyson, Alfred Tennyson, Baron, 1809-1892",,"Naxos AudioBooks,",p2009.
# Digital,OverDrive,AUDIOBOOK,2014,8,1,The Beach Club: A Novel (unabridged) (Unabridged),Elin Hilderbrand,"Fiction, Literature",Macmillan Audio,2013
# Digital,OverDrive,EBOOK,2014,8,1,"The Secret Adversary: Tommy and Tuppence Series, Book 1",Agatha Christie,"Classic Literature, Fiction, Literature, Mystery",The Floating Press,2010
# Physical,Horizon,BOOK,2017,6,9,Messy Molly / Jo Williamson.,"Williamson, Jo,","Cleanliness Juvenile fiction, Dogs Juvenile fiction, Cleanliness Fiction, Dogs Fiction","Little Bee Books,",[2016]

# %% [markdown]
# Por fines didacticos, solo se revisan los primeros 10M de registros

# %%
#subsample of 10M of file
# !head -n 1000000 checkouts-by-title.csv > checkouts10M.csv

# %% [markdown]
# Contamos las líneas del archivo original, son ~34M
#
# Comandos
# wc <- word count, para hacer conteo en general de caracteres, el argumento -l hace que cuente las líneas

# %%
# %%time
# !wc -l checkouts-by-title.csv
# Out:
# 34892624 checkouts-by-title.csv
# CPU times: user 152 ms, sys: 31.2 ms, total: 183 ms
# Wall time: 29.4 s

# %% [markdown]
# Verificamos que el archivo muestra efectivamente tiene 10M

# %%
# %%time
# !wc -l checkouts10M.csv
# Out:
# 1000000 checkouts10M.csv
# CPU times: user 10.8 ms, sys: 4.42 ms, total: 15.3 ms
# Wall time: 817 ms

# %% [markdown]
# Setteamos el nombre del archivo y el número de lineas a procesar

# %%
filename = "checkouts10M.csv"
lines = 1000000

# %% [markdown]
# #En Paralelo

# %%
#threads = mp.cpu_count() #threads disponibles en la máquina
threads = 4
num_lines = lines
split_size = num_lines // threads if num_lines // threads > 0 else 1 #Tamaños a procesar por cada procesador
parts = [x for x in range(0, num_lines, split_size)] #Donde inicia 
parts
# Out:
# [0, 250000, 500000, 750000]

# %%
def countWordsInTitles(filename, chunksize, start):
  wordCount = {}
  counter = 0
  print("Calling from {}".format(start))
  for current_line in range(start, (start+chunksize)+1):
    ln = linecache.getline(filename, current_line)
    try:
      words = ln.split(",")[6].split(" ")
      #print(words)
      for w in words:
        if w.upper() not in wordCount.keys():
          wordCount[w.upper()] = 0
        wordCount[w.upper()] += 1
    except Exception as e:
      print("null title {} ".format(str(e)))      
    counter += 1
    if counter % 1000000 == 0:
      print("From {start} in line {counter}".format(start=start, counter=counter))
  return wordCount

# %%
# %%time
pool = mp.Pool(processes=threads)
func = partial(countWordsInTitles, filename, split_size)
res = pool.map(func, parts)
pool.close()
pool.join()
# "res" entonces es una lista de diccionarios con las cuentas de palabras por cada worker.
# Out:
# Calling from 0
# Calling from 500000
# Calling from 250000
# Calling from 750000
# null title list index out of range
# CPU times: user 183 ms, sys: 132 ms, total: 315 ms
# Wall time: 7.42 s

# %% [markdown]
# ## De forma secuencial

# %%
# %%time
wordCount = {}
counter = 0
#f1 = open(filename, 'r')
for i in range(1,lines):
  ln = linecache.getline(filename, i)
  try:    
    words = ln.split(',')[6].split(" ")  
    for w in words:
      if w.upper() not in wordCount.keys():
        wordCount[w.upper()] = 0
      wordCount[w.upper()] += 1
  except Exception as e:
    print("null title {} ".format(str(e)))      
  counter += 1
  if counter % 1000000 == 0:
    print("From {start} in line {counter}".format(start=0, counter=counter))
# Out:
# CPU times: user 8.87 s, sys: 63.6 ms, total: 8.94 s
# Wall time: 8.95 s

# %%
#Este es el sweetspot, se puede ver que secuencial tarda un poco mas, "aprox 10% en este caso"

# %%
res[0]
# Out:
# {'TITLE': 72,
#  "MCGRAW-HILL'S": 11,
#  'DICTIONARY': 830,
#  'OF': 105321,
#  'AMERICAN': 6294,
#  'SLANG': 50,
#  'AND': 85054,
#  'COLLOQUIAL': 24,
#  'EXPRESSIONS': 37,
#  '/': 171853,
#  'RICHARD': 2767,
#  'A.': 2154,
#  'SPEARS.': 25,
#  '"EMMA': 3,
#  'RED': 1728,
#  'MIDNIGHT': 555,
#  'JUST': 1020,
#  'THE': 176736,
#  'FINANCIAL': 450,
#  'FACTS': 307,
#  'HOW': 10242,
#  'TO': 44359,
#  'IDENTIFY': 62,
#  'NUGGETS': 12,
#  'USABLE': 14,
#  'NEWS': 294,
#  'MINIMIZE': 11,
#  'INFORMATION': 267,
#  'OVERLOAD': 12,
#  'SINGLE': 210,
#  'SHARD': 13,
#  'PAUL': 2303,
#  "KIRK'S": 3,
#  'CHAMPIONSHIP': 35,
#  'BARBECUE': 62,
#  ':': 76332,
#  'BBQ': 22,
#  'YOUR': 12861,
#  'WAY': 2802,
#  'GREATNESS': 51,
#  'WITH': 19255,
#  '575': 2,
#  "LIP-SMACKIN'": 2,
#  'RECIPES': 2573,
#  'FROM': 16645,
#  'BARON': 61,
#  'KIRK': 103,
#  'BOB': 1090,
#  'LYON.': 32,
#  'LIVE': 2351,
#  'THIS': 1660,
#  'IS': 5136,
#  'HOUSE': 3116,
#  '"BANDIDO': 1,
#  'OSCAR': 223,
#  '""ZETA""': 1,
#  'ACOSTA': 1,
#  'CHICANO': 8,
#  'EXPERIENCE': 433,
#  'ILAN': 19,
#  'STAVANS."': 1,
#  'COLUMBIA': 610,
#  'RIVER': 995,
#  'COLLECTION': 2121,
#  'JOURNEY': 2171,
#  'STORIES': 6042,
#  'MIGRATION': 64,
#  'CYNTHIA': 602,
#  'RYLANT': 262,
#  ';': 69816,
#  'ILLUSTRATED': 17446,
#  'BY': 97996,
#  'LAMBERT': 20,
#  'DAVIS.': 379,
#  'I': 6292,
#  'WANNA': 63,
#  'TAKE': 758,
#  'ME': 3662,
#  'A': 75533,
#  'PICTURE': 1760,
#  'TEACHING': 388,
#  'PHOTOGRAPHY': 1946,
#  'WRITING': 1237,
#  'CHILDREN': 2172,
#  'GOOGIE': 4,
#  'FIFTIES': 56,
#  'COFFEE': 138,
#  'SHOP': 301,
#  'ARCHITECTURE': 503,
#  'ALAN': 1060,
#  'HESS.': 56,
#  'LAZARUS': 53,
#  'HEART': 2086,
#  'SOME': 491,
#  'BEST': 5007,
#  'BIAŁA': 2,
#  'BLUZKA': 2,
#  'AGNIESZKA': 7,
#  'OSIECKA.': 2,
#  'RETRO': 39,
#  'AN': 11323,
#  'AMOS': 88,
#  'WALKER': 225,
#  'NOVEL': 12737,
#  'TERRIFIC': 73,
#  'TOTES': 11,
#  'CARRYALLS': 4,
#  '40': 339,
#  'BAGS': 98,
#  'SEW': 84,
#  'FOR': 29594,
#  'SHOPPING': 100,
#  'WORKING': 442,
#  'HIKING': 238,
#  'BIKING': 39,
#  'MORE': 2927,
#  'MARATHON': 81,
#  'RUNNING': 371,
#  'COMPLETE': 6258,
#  'TRAINING': 598,
#  'GUIDE': 13919,
#  'CRIMES': 159,
#  'CONSCIENCE': 103,
#  'NADINE': 72,
#  'GORDIMER.': 25,
#  'YELLOWSTONE': 101,
#  'WATERFALLS': 24,
#  'THEIR': 1612,
#  'DISCOVERY': 335,
#  'ART': 5708,
#  'DORA': 170,
#  'CARRINGTON': 8,
#  'JANE': 1816,
#  'HILL': 485,
#  'FOREWORD': 2451,
#  'MICHAEL': 3630,
#  'HOLROYD.': 7,
#  'SEVERED': 7,
#  'HEAD': 381,
#  'KHOCHU': 3,
#  'BYT': 2,
#  'DVORNIKOM': 2,
#  'MASS': 170,
#  'ROMANTIC': 315,
#  'BLOODY': 118,
#  'GROUND': 271,
#  'LAPU': 9,
#  'ELECTRONIC': 99,
#  'SWING': 207,
#  'TRADING': 137,
#  'MAXIMUM': 122,
#  'PROFIT': 189,
#  'DISCOVER': 278,
#  'PROFESSIONAL': 335,
#  'STRATEGY': 187,
#  'THAT': 3670,
#  'COMBINES': 5,
#  'DAY': 3429,
#  'LONG': 1241,
#  'TERM': 58,
#  'INVESTING': 337,
#  'TECHNIQUES': 1666,
#  '"GENERATION': 9,
#  'RX': 35,
#  'PRESCRIPTION': 120,
#  'DRUGS': 156,
#  'ARE': 2119,
#  'ALTERING': 15,
#  'LIVES': 1037,
#  'SECOND': 1106,
#  'TIME': 4103,
#  'AROUND': 1136,
#  'CATHERINE': 532,
#  'DE': 5520,
#  'MEDICI': 30,
#  'RENAISSANCE': 364,
#  'QUEEN': 909,
#  'FRANCE': 548,
#  'MEN': 1592,
#  'IN': 37128,
#  'KNITS': 298,
#  'SWEATERS': 50,
#  'KNIT': 262,
#  'HE': 521,
#  'WILL': 1386,
#  'WEAR': 148,
#  'TARA': 68,
#  'JON': 454,
#  'MANNING.': 58,
#  'CURE': 202,
#  'CRUSHES': 6,
#  'OTHER': 4107,
#  'DEADLY': 341,
#  'PLAGUES': 24,
#  'MOTHER': 859,
#  'GOOSE': 230,
#  'SPANISH': 889,
#  'POESIAS': 3,
#  'LA': 1954,
#  'MADRE': 36,
#  'OCA': 2,
#  'STAR': 1410,
#  'WARS': 779,
#  'AGO': 66,
#  'VOLUME': 3871,
#  '7': 1082,
#  'FAR': 423,
#  'AWAY': 553,
#  'ULTIMATE': 1513,
#  'X': 700,
#  'VOL': 3035,
#  '6': 1108,
#  'RETURN': 681,
#  'KING': 1821,
#  'ZERO': 230,
#  'GRANDPARENTS': 23,
#  'MICHELLE': 240,
#  'EDWARDS.': 103,
#  '"MODERN': 26,
#  'COPPER': 47,
#  'COINS': 20,
#  'MUHAMMADAN': 1,
#  'STATES': 672,
#  'TURKEY': 161,
#  'KLAVIERSONATEN': 11,
#  'PIANO': 1746,
#  'SONATAS': 263,
#  'ISLA': 20,
#  'ARTHUR': 1025,
#  'DORROS': 33,
#  'ELISA': 89,
#  'KLEVEN.': 28,
#  'ELVIRA': 19,
#  'MADIGAN': 7,
#  'RAISING': 414,
#  'HOPE': 643,
#  'KATIE': 235,
#  'WILLARD.': 16,
#  'LITTLE': 3672,
#  'LOVE': 5883,
#  'STORY': 9128,
#  'ROLAND': 107,
#  'MERULLO.': 8,
#  'ELDORADO': 6,
#  'RED.': 5,
#  'WILLS': 71,
#  'HIS': 2031,
#  'TEXAS': 279,
#  'PLAYBOYS': 15,
#  'ANTHOLOGY': 813,
#  '1935': 69,
#  '1973': 49,
#  'SOMETHIN': 9,
#  'EXTRA': 68,
#  'TOWARD': 176,
#  'END': 1072,
#  'JOHN': 6569,
#  'UPDIKE.': 52,
#  'CURIOUS': 407,
#  'INCIDENT': 67,
#  'DOG': 1877,
#  'NIGHT-TIME': 9,
#  '[SOUND': 24838,
#  'RECORDING]': 21232,
#  'MARK': 1706,
#  'HADDON.': 16,
#  'SEQUENCE': 26,
#  'WAKING': 94,
#  'TIGER': 380,
#  'HEALING': 1113,
#  'TRAUMA': 86,
#  'INNATE': 5,
#  'CAPACITY': 16,
#  'TRANSFORM': 213,
#  'OVERWHELMING': 8,
#  'EXPERIENCES': 113,
#  'PETER': 2690,
#  'LEVINE': 88,
#  'ANN': 1433,
#  'FREDERICK.': 16,
#  'MOON': 1705,
#  'HANDBOOKS': 101,
#  'ARGENTINA': 59,
#  'VICTORIAN': 175,
#  'FRAME': 66,
#  'MIND': 1508,
#  '1830': 11,
#  '1870': 21,
#  'SPEAKING': 136,
#  'BEAUTY': 783,
#  'DENIS': 75,
#  'DONOGHUE.': 17,
#  'NO': 4245,
#  'LIKE': 1528,
#  'SHOW': 688,
#  'HERMUX': 19,
#  'TANTAMOQ': 19,
#  'ADVENTURE': 1156,
#  'WEIR': 46,
#  'PRACTICAL': 1077,
#  'WATER': 1141,
#  'GARDENING': 544,
#  'BLINDSIDE': 4,
#  'FBI': 109,
#  'THRILLER': 172,
#  'DIVIDED': 111,
#  'EPIDEMIC': 95,
#  'MINDBODY': 12,
#  'DISORDERS': 156,
#  'E.': 1497,
#  'SARNO.': 8,
#  'FLORAS': 12,
#  'BLANKET': 43,
#  '"WILD': 51,
#  'IRELAND': 305,
#  "TRAVELLER'S": 38,
#  'BRENDAN': 60,
#  'LEHANE': 2,
#  'WORLDS': 854,
#  'TREK': 168,
#  'DEEP': 599,
#  'SPACE': 998,
#  'NINE': 370,
#  'TWO': 2464,
#  'TRILL': 8,
#  'BAJOR': 1,
#  'TRAVELLING': 16,
#  'PATH': 591,
#  'SAYINGS': 28,
#  'SUFI': 36,
#  'MASTERS': 393,
#  'MUNICH': 24,
#  'BAVARIA': 43,
#  'GET': 1797,
#  'CONTROL': 454,
#  'LIFE': 11014,
#  'INTRODUCTION': 3409,
#  'HEALTH': 1255,
#  'CARE': 767,
#  'WORKERS': 72,
#  'COMMUNICATION': 190,
#  'CULTURE': 858,
#  'JIMI': 79,
#  'HENDRIX': 77,
#  'AT': 6548,
#  'WOODSTOCK': 38,
#  'PURSENALITIES': 2,
#  '20': 548,
#  'GREAT': 4489,
#  'KNITTED': 89,
#  'FELTED': 20,
#  'EVA': 185,
#  'WIECHMANN.': 2,
#  'CROWD': 71,
#  'KID': 428,
#  'DALOM': 1,
#  'KIDS': 1921,
#  'SPLASH': 80,
#  'READ': 686,
#  'MUSIC': 4525,
#  'TODAY': 385,
#  'V': 701,
#  '1': 4253,
#  'UNDERSTANDING': 812,
#  'NOTATION': 15,
#  'IF': 825,
#  'YOU': 9476,
#  'CAN': 2561,
#  'STAND': 276,
#  'HEAT': 258,
#  'TALES': 2653,
#  'CHEFS': 114,
#  'RESTAURATEURS': 3,
#  'FEEL': 361,
#  'FEAR': 516,
#  'DO': 2348,
#  'IT': 4009,
#  'ANYWAY': 17,
#  'SOUTH': 834,
#  'AFRICAN': 764,
#  'CITY': 2056,
#  'SAM': 508,
#  'SAMURAI': 252,
#  'SCIESZKA': 60,
#  'ADAM': 411,
#  'MCCAULEY.': 38,
#  'STRUCTURE': 110,
#  'SCIENTIFIC': 273,
#  'REVOLUTIONS': 24,
#  'THOMAS': 1702,
#  'S.': 1211,
#  'KUHN.': 37,
#  'BLIND': 265,
#  'MAN': 3716,
#  'SEE': 643,
#  'MUCH': 355,
#  'CAT': 1622,
#  'HAT': 318,
#  'COMES': 464,
#  'BACK': 1399,
#  'HOP': 184,
#  'ON': 12077,
#  'POP': 332,
#  'SELL': 196,
#  'CONDO': 15,
#  'CO': 112,
#  'OP': 873,
#  'BLACK': 2678,
#  'HISTORY': 5481,
#  'BEGINNERS.': 25,
#  'PROUD': 64,
#  'TOWER': 180,
#  'PORTRAIT': 479,
#  'WORLD': 8090,
#  'BEFORE': 1073,
#  'WAR': 3942,
#  '1890': 23,
#  '1914': 36,
#  'GORDIMER': 4,
#  "BYRD'S": 2,
#  'REMINDER': 3,
#  'ROBERT': 3747,
#  'WEINSTOCK.': 4,
#  'ROAD': 1460,
#  'MOROCCO': 72,
#  'GETTING': 939,
#  'EVEN': 255,
#  'DENSITY': 12,
#  'SOULS': 212,
#  'SONGS': 2509,
#  'MOMENTS': 180,
#  'OPASNOE': 4,
#  'OKRUZHENIE': 3,
#  'ROMAN': 748,
#  'NATALI': 4,
#  'PITERS.': 3,
#  'GREEN': 1250,
#  'RIPPER': 21,
#  'THIRD': 683,
#  'ANGEL': 688,
#  'STOLEN': 158,
#  'CHILD': 1513,
#  'ASPECTS': 44,
#  'AUTISM': 141,
#  'ASPERGER': 63,
#  'SYNDROME': 238,
#  'EXPLORING': 491,
#  "WASHINGTON'S": 83,
#  'PAST': 607,
#  'RUTH': 599,
#  'CARMELA': 19,
#  'ALEXANDER': 640,
#  'DAVID': 5366,
#  'NICANDRI': 3,
#  'PHOTOGRAPHS': 2670,
#  'LOUIS': 695,
#  'KIRK.': 54,
#  'BARKLEYS': 5,
#  'BROADWAY': 477,
#  '<UNKNOWN': 2217,
#  'TITLE>': 2217,
#  'LEGEND': 777,
#  'SLEEPY': 122,
#  'HOLLOW': 106,
#  'ROMIETTE': 6,
#  'JULIO': 41,
#  'PRE-ALGEBRA': 22,
#  'DEMYSTIFIED': 60,
#  'ALLAN': 313,
#  'G.': 908,
#  'BLUMAN.': 4,
#  'REMARKABLE': 280,
#  'FARKLE': 6,
#  'MCBRIDE': 12,
#  'LITHGOW': 24,
#  'C.F.': 22,
#  'PAYNE.': 54,
#  '"READING': 16,
#  'CONQUERORS': 8,
#  'IMITATION': 21,
#  'CHOCOLATE': 435,
#  'HOLIDAYS': 201,
#  'UNFORGETTABLE': 75,
#  'DESSERTS': 191,
#  'EVERY': 1391,
#  'SEASON': 2435,
#  'SCARY': 185,
#  'MOVIE': 670,
#  'CLASSIC': 1145,
#  'MILLINERY': 3,
#  'MAKING': 1978,
#  '&': 10538,
#  'DESIGNING': 247,
#  "TODAY'S": 126,
#  'HATS': 105,
#  'ALBRIZIO': 2,
#  'COAUTHORED': 2,
#  'OSNAT': 2,
#  'LUSTIG': 8,
#  'TED': 490,
#  'MORRISON.': 96,
#  '"SHOPPING': 5,
#  'CENTERS': 25,
#  'RETAIL': 53,
#  'PROPERTIES': 39,
#  'INVESTMENT': 151,
#  'GUITARS': 39,
#  'GOLDEN': 878,
#  'TRIANGLE': 74,
#  'FOLK': 586,
#  'MYANMAR': 17,
#  '(BURMA).': 4,
#  'VOL.': 1215,
#  '2.': 33,
#  'BIG': 3248,
#  'BEAUTIFUL': 931,
#  'LARGE': 104,
#  'PUPPETS': 71,
#  'BAREFOOT': 106,
#  'CONTESSA': 13,
#  'ROBBING': 4,
#  'BEES': 132,
#  'BIOGRAPHY': 859,
#  'HONEY': 221,
#  'SWEET': 693,
#  'LIQUID': 43,
#  'GOLD': 858,
#  'SEDUCED': 48,
#  'VACATIONS': 30,
#  'MARITIMES': 1,
#  'TOURBOOK': 1,
#  'NOVA': 101,
#  'SCOTIA': 3,
#  'PRINCE': 630,
#  'EDWARD': 919,
#  'ISLAND': 1001,
#  'NEW': 8017,
#  'BRUNSWICK': 10,
#  'PLUS': 232,
#  'NEWFOUNDLAND': 7,
#  'LABRADOR': 19,
#  'THIN': 191,
#  'PEOPLE': 2197,
#  'DONT': 899,
#  'CLEAN': 176,
#  'PLATES': 60,
#  'SIMPLE': 1470,
#  'LIFESTYLE': 95,
#  'CHOICES': 164,
#  'PERMANENT': 75,
#  'WEIGHT': 540,
#  'LOSS': 400,
#  'DEEPEST': 40,
#  'PURPLE': 174,
#  'VERY': 887,
#  'PURPLE.': 4,
#  'BEATLES': 154,
#  '2': 4409,
#  'RECORDING].': 3604,
#  'CHANGES': 164,
#  'SAMANTHA': 113,
#  'WINTER': 746,
#  '"FLINGS': 1,
#  'AXE': 7,
#  'MAKERS': 100,
#  'NORTH': 1167,
#  'AMERICA': 3277,
#  'KLENMAN.': 1,
#  'NETHERLANDS': 45,
#  'ITSY': 18,
#  'BITSY': 24,
#  'SMART': 586,
#  'SPIDER': 410,
#  'BLADE': 160,
#  'IMMORTAL': 124,
#  'AUTUMN': 192,
#  'FROST': 107,
#  'NEVSKY': 14,
#  '"WATER': 23,
#  'WITCH': 439,
#  '[TEXT': 5361,
#  '(LARGE': 5230,
#  'PRINT)]': 5230,
#  'CONNIE': 122,
#  'WILLIS': 84,
#  'ANXIETY': 167,
#  'DEPRESSION': 354,
#  'DECEPTION': 241,
#  'ELIZABETH': 1465,
#  'GEORGE.': 93,
#  'SISTER': 464,
#  'BASQUIAT': 16,
#  'ROSE': 776,
#  'MANS': 283,
#  'LAND': 1177,
#  'OTHELLO': 58,
#  'STUDENT': 156,
#  'CASEBOOK': 79,
#  'ISSUES': 99,
#  'SOURCES': 94,
#  'HISTORICAL': 380,
#  'DOCUMENTS': 59,
#  'CHIEFTAINS': 16,
#  'MINNIE': 115,
#  'MOO': 167,
#  'MEET': 382,
#  'FRANKENSWINE': 4,
#  'DENYS': 100,
#  'CAZET.': 80,
#  'PAN': 185,
#  'ILLM': 4503,
#  'HEBREW': 92,
#  'GODDESS': 251,
#  'GLORY': 330,
#  'YING': 301,
#  'ER': 255,
#  'YI': 804,
#  'ZHI': 638,
#  'XI': 201,
#  'WOODLAND': 24,
#  'ANIMALS': 921,
#  'THORNHOLD': 1,
#  'DRAGONSONG': 7,
#  'DUE': 44,
#  'PREPARATIONS': 3,
#  'PLAGUE': 132,
#  'JANETTE': 23,
#  'TURNER': 149,
#  'HOSPITAL.': 2,
#  'EDEN': 194,
#  'WEBLOG': 2,
#  'HANDBOOK': 1597,
#  'ADVICE': 386,
#  'CREATING': 960,
#  'MAINTAINING': 65,
#  'BLOG': 43,
#  'OKAYAMA': 1,
#  'ONNA': 44,
#  'IWAI': 7,
#  'SHIMAKO.': 7,
#  'MY': 6713,
#  'MOMMY': 109,
#  'BECAUSE': 128,
#  'COOKING': 1294,
#  'EATING': 524,
#  'BEER': 123,
#  '50': 868,
#  'BREWMASTERS': 4,
#  'TALK': 718,
#  'ABOUT': 4166,
#  'FOOD': 1677,
#  'TRAIN': 550,
#  'DRAGON': 990,
#  'RECORD': 198,
#  'AIR': 568,
#  'BATTLE': 811,
#  'FORCE': 295,
#  'PHONICS': 73,
#  'EXPOSED': 36,
#  'RESISTING': 13,
#  'SYSTEMATIC': 19,
#  'DIRECT': 52,
#  'INTENSE': 12,
#  'INSTRUCTION': 130,
#  'J.': 2369,
#  'MEYER.': 87,
#  'BETTER': 797,
#  'HOMES': 265,
#  'GARDENS': 606,
#  'COOK': 494,
#  'BOOK': 8583,
#  'OD': 4,
#  'MAGIC': 1877,
#  'KINDRED': 34,
#  'SPIRITS': 208,
#  'TRIBUTE': 257,
#  'JOHNNY': 393,
#  'CASH.': 71,
#  'WHITNEY': 70,
#  'HOUSTON.': 22,
#  'MEMOIR': 1395,
#  'JUDITH': 460,
#  'BARRINGTON.': 1,
#  'SMILING': 23,
#  'GWENYTH': 33,
#  'SWAIN.': 26,
#  'LEAN': 76,
#  'WORKPLACE': 87,
#  'ENVIRONMENT': 130,
#  'MISS': 764,
#  'PIGGYS': 7,
#  'NIGHT': 2840,
#  'OUT': 2393,
#  'OPENGL': 2,
#  'SUPERBIBLE': 2,
#  'FROG': 334,
#  'UP': 2712,
#  'CHOCOHOLIC': 23,
#  'MYSTERY': 4295,
#  'SERIES': 4766,
#  'MURDERS': 258,
#  'SERGEANT': 15,
#  'YORK': 919,
#  'PEOPLE.': 27,
#  'BROWNING': 40,
#  'VERSION': 240,
#  'BUFFY': 83,
#  'VAMPIRE': 428,
#  'SLAYER': 88,
#  '"THE': 9143,
#  'BRAVE': 298,
#  'TOASTER': 26,
#  'GOES': 830,
#  'MARS': 306,
#  '[VIDEORECORDING]': 15358,
#  'WALT': 715,
#  'DISNEY': 731,
#  'HOME': 4404,
#  'VIDEO': 571,
#  'PRESENTS': 1704,
#  'HYPERION': 29,
#  'STUDIO/KUSHNER-LOCKE': 6,
#  'PRODUCTION': 3835,
#  'SCREENPLAY': 1750,
#  'TRIAL': 189,
#  'JOURNAL': 418,
#  'HORRIBLE': 99,
#  'HARRY': 905,
#  'GOOG': 6,
#  'SUZY': 72,
#  'KLINE': 53,
#  'PICTURES': 6544,
#  'FRANK': 1220,
#  'REMKIEWICZ.': 103,
#  'HOLIDAY': 501,
#  'CRAFTS': 519,
#  'EVER': 821,
#  '"ECKERT': 1,
#  'ANIMAL': 844,
#  'PHYSIOLOGY': 34,
#  'MECHANISMS': 9,
#  'ADAPTATIONS': 14,
#  'RANDALL': 80,
#  'SEX': 984,
#  'MACHINE': 487,
#  'JAMES': 3252,
#  'BROWN.': 629,
#  'WHEN': 2040,
#  'LIVING': 2377,
#  'HURTS': 44,
#  'WHAT': 4024,
#  'YOURSELF': 897,
#  'OR': 2114,
#  'SOMEONE': 174,
#  'WHO': 3293,
#  'FEELS': 63,
#  'DISCOURAGED': 2,
#  'SAD': 81,
#  'LONELY': 193,
#  'HOPELESS': 22,
#  'ANGRY': 136,
#  'FRUSTRATED': 14,
#  'UNHAPPY': 12,
#  'BORED': 17,
#  'DEPRESSED': 28,
#  'SUICIDAL': 6,
#  'VILLA': 68,
#  'REDUCED': 18,
#  'CIRCUMSTANCES': 75,
#  'MCCALL': 167,
#  'SMITH': 515,
#  'ILLUSTRATIONS': 3314,
#  'IAIN': 89,
#  'MCINTOSH.': 39,
#  '"A': 1051,
#  'MANUAL': 843,
#  'WRITERS': 711,
#  'PAPERS': 138,
#  'SIBYL': 7,
#  'HER': 1251,
#  'GRAVE': 216,
#  'SHELTERS': 20,
#  'STONE': 857,
#  'HORSES': 245,
#  'EASTMAN': 8,
#  'INTRODUCTIONS': 46,
#  'SMILEY': 14,
#  'WILLIAM': 2396,
#  'H.': 1023,
#  'GASS.': 6,
#  'JUDY': 595,
#  'GARLAND': 79,
#  'TELEVISION': 1238,
#  'WORKS': 876,
#  'STILL': 546,
#  'CHICKENS': 105,
#  'STARTING': 228,
#  'OVER': 1708,
#  'SEA': 1692,
#  'GOLDHAMMER.': 14,
#  'BERENSTAIN': 297,
#  'BEARS': 632,
#  'MIRRORS': 80,
#  'AFFAIRS': 86,
#  'WE': 2153,
#  'ONLY': 707,
#  'FRIENDS': 1424,
#  'HAVE': 1178,
#  'JURY': 100,
#  'PEERS': 10,
#  'STICKS': 39,
#  'SCONES': 20,
#  'CQ': 11,
#  'BOUND': 133,
#  'ISRAEL': 217,
#  'TWENTY': 309,
#  'ONE': 4552,
#  'BALLOONS': 33,
#  'PASO': 32,
#  'SCOUNDREL': 33,
#  'AFRO': 78,
#  'CARIBBEAN': 204,
#  'STEP': 1490,
#  'DEBRA': 144,
#  'BONO': 17,
#  'IMAGES': 280,
#  'AFRICA': 698,
#  '"GYPSY': 4,
#  'KABBALAH': 52,
#  'MONEY': 1184,
#  'INSIGHTS': 89,
#  'LIVELIHOOD': 6,
#  'BUSINESS': 1738,
#  'ALL': 4266,
#  'FORMS': 138,
#  'ECONOMIC': 152,
#  'BEHAVIOR': 307,
#  'TRIO': 180,
#  'MEMORIAS': 6,
#  'UNA': 291,
#  'GEISHA': 48,
#  'FOX': 933,
#  'JOB': 628,
#  'FRENCH': 1440,
#  'WOMEN': 2380,
#  'GASTRONOMIC': 11,
#  'MADELEINE': 124,
#  'KAMMAN.': 4,
#  'OCTOBER': 80,
#  'SUITE': 257,
#  'SUNDAYS': 34,
#  'MOOSEWOOD': 64,
#  'RESTAURANT': 214,
#  'COLLECTIVE.': 37,
#  'ANOREXIA': 25,
#  'DIARIES': 297,
#  'DAUGHTERS': 271,
#  'TRIUMPH': 210,
#  'TEENAGE': 169,
#  'STRAWBERRY': 64,
#  'SUNDAY': 229,
#  'MARSHALL': 192,
#  'TANNER': 62,
#  'HUNT': 365,
#  'POINT': 366,
#  'INSIDE': 1341,
#  'CLASSIFIED': 12,
#  'ANTI-GRAVITY': 5,
#  'TECHNOLOGY': 225,
#  'NICK': 419,
#  'COOK.': 97,
#  'MOLE': 83,
#  'SISTERS': 550,
#  'RAINY': 78,
#  'WHOLESOME': 21,
#  'FOODS': 315,
#  'PASSIONATE': 138,
#  'Z': 459,
#  'EARTHS': 43,
#  'HEALTHY': 827,
#  'OFFERINGS': 19,
#  'THAN': 1169,
#  '140': 34,
#  'DELICIOUS': 461,
#  'NUTRITIOUS': 28,
#  'CASA': 63,
#  'LOS': 575,
#  'ESP¡RITUS': 6,
#  '101': 632,
#  'PILATES': 242,
#  'DUMMIES': 1135,
#  'HAI': 174,
#  'SHANG': 134,
#  'FAN': 145,
#  'HUA': 472,
#  'MENG': 86,
#  'WANG': 293,
#  'ANYI': 12,
#  'ZHU.': 697,
#  'PLANS': 257,
#  'WORK': 1582,
#  'INCLUDES': 101,
#  'ACTUAL': 42,
#  'SUCCESSFULLY': 45,
#  'ATTRACTED': 6,
#  'FINANCING': 13,
#  'DEANS': 8,
#  'MOE': 18,
#  'PRAGER': 7,
#  'POND': 128,
#  'FISH': 589,
#  'CREATURES': 268,
#  'HELEN': 597,
#  'NASH.': 58,
#  'THREE': 2141,
#  'JUMP': 152,
#  'DANCER': 162,
#  'DARK': 1652,
#  '1918': 47,
#  'EVERYTHING': 1650,
#  'DIGITAL': 540,
#  'CAMERA': 148,
#  'BILL': 1350,
#  'RIGHTS': 374,
#  'PAINS': 17,
#  'YOUTH': 251,
#  'FERDINAND': 28,
#  'BRUCKNER': 8,
#  'TRANSLATED': 4034,
#  'DAPHNE': 48,
#  'MOORE.': 203,
#  'TURNING': 239,
#  'TIM': 762,
#  'WINTON.': 14,
#  'WAS': 967,
#  'ELEANOR': 241,
#  'RIGBY?': 2,
#  '908': 2,
#  'QUESTIONS': 599,
#  'ANSWERS': 356,
#  'BRANDON': 75,
#  'TOROPOV.': 4,
#  'THINGS': 1387,
#  'RHODES': 19,
#  'CECIL': 59,
#  'SANDWICHED': 1,
#  'IZUMRUDY': 1,
#  'PROROKA': 1,
#  'TOTEM': 63,
#  'POLES': 49,
#  'JENNIFER': 624,
#  'FRANTZ': 7,
#  'ALLEN': 409,
#  'EITZEN.': 22,
#  'VOYAGE': 357,
#  'AMISTAD': 16,
#  'QUEST': 629,
#  'FREEDOM': 791,
#  'SCHWINN': 1,
#  'BICYCLES': 13,
#  'JAY': 364,
#  'PRIDMORE': 4,
#  'JIM': 1403,
#  'HURD.': 33,
#  'FLY': 453,
#  'AFTER': 1112,
#  'SILENCE': 299,
#  'RAPE': 50,
#  'MAZE': 75,
#  'INSPECTOR': 367,
#  'ALVAREZ': 33,
#  'HISTORIC': 158,
#  'WASHINGTON': 1165,
#  'STATE': 542,
#  'TRAVEL': 609,
#  'HUNDREDS': 112,
#  'PLACES': 540,
#  'EVERGREEN': 40,
#  'GEORGE': 1912,
#  'JAN': 656,
#  'ROBERTS.': 299,
#  'ALONE': 297,
#  'ORPHANS': 30,
#  'ORPHANAGES': 2,
#  'REEF.': 8,
#  'TORSO': 8,
#  'TRUE': 2408,
#  'CRIME': 488,
#  'GRAPHIC': 341,
#  'ETUDES': 16,
#  '10': 1047,
#  'BARCAROLLE': 7,
#  '60': 175,
#  'SONATA': 197,
#  'CIRCLING': 8,
#  'DRAIN': 5,
#  'GIFT': 457,
#  'MAGI': 19,
#  'O.': 274,
#  'HENRY': 1119,
#  ...}

# %%
#Eso fue el mapper, este es el reduce
#cuantos mappers teniamos?
len(res)
# Out:
# 2

# %%
reduced = {} #Creamos el diccionario reducido
for i in res: #Para cada elemento del mapper
  for key in i.keys(): #Recorremos las llaves
    if key not in reduced.keys(): #si no existe la creamos con el primer valor que encuentra para esa llave
      reduced[key] = i[key] 
    else:
      reduced[key] = reduced[key] + i[key] #si existe, entonces le suma el valor

# %%
print("Total keys in first", len(res[0].keys()))
print("Total keys in second", len(res[1].keys()))
# Out:
# Total keys in first 152760
# Total keys in second 194153

# %%
print("Total Keys reduced", len(reduced.keys()))
# Out:
# Total Keys reduced 240508

# %%
reduced.keys() #llaves, tomar ejemplo aleatorio
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
reduced["AMERICAN"]
# Out:
# 11719

# %%
res[0]["AMERICAN"]
# Out:
# 6294

# %%
res[1]["AMERICAN"]
# Out:
# 5425

# %%
res[0]["AMERICAN"] + res[1]["AMERICAN"]
# Out:
# 11719
